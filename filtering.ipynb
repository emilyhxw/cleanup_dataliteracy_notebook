# %% [markdown]
# # Final Data used for Visualization

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load Data

# %%
df = pd.read_csv("/Users/emilywu/Desktop/DataLiteracy/MiniProjekt/clean_shark_attacks_updated.csv")

# %%
display(df)
# Out:
#       Unnamed: 0.1  Unnamed: 0                  Date  Year        Type  \
# 0                0           0          10th January  2026  Unprovoked
# 1                1           1           8th January  2026  Unprovoked
# 2                2           2          3rd January   2026  Unprovoked
# 3                3           3         21st December  2025  Unprovoked
# 4                4           4         12th December  2025  Unprovoked
# ...            ...         ...                   ...   ...         ...
# 2490          2490        2808           03-Feb-2000  2000  Unprovoked
# 2491          2491        2809           01-Feb-2000  2000  Unprovoked
# 2492          2492        2810  Reported 28-Jan-2000  2000  Watercraft
# 2493          2493        2811           05-Jan-2000  2000  Unprovoked
# 2494          2494        2812                  2000  2000  Watercraft
#
#                 Country                                           Location  \
# ...

# %% [markdown]
# Filter Data: in US, up until 2023, Fatal

# %%
df_us_fatal_upto2023 = df[
    (df["CountryCode"] == "US") &
    (df["Year"] <= 2023) &
    (df["Fatal Y/N"] == "Y")
].copy()

# %%
display(df_us_fatal_upto2023)
df_us_fatal_upto2023.count()
# Out:
#       Unnamed: 0.1  Unnamed: 0          Date  Year          Type Country  \
# 116            116         122   30 Dec-2023  2023    Unprovoked     USA
# 140            140         149   01 Oct-2023  2023    Unprovoked     USA
# 216            216         235   08-Dec-2022  2022    Unprovoked     USA
# 289            289         313   26-Feb-2022  2022    Unprovoked     USA
# 303            303         330   24-Dec-2021  2021    Unprovoked     USA
# 342            342         374   10-Jul-2021  2021    Unprovoked     USA
# 408            408         444   08-Dec-2020  2020    Unprovoked     USA
# 449            449         490   27-Jul-2020  2020    Unprovoked     USA
# 473            473         515   09-May-2020  2020    Unprovoked     USA
# 566            566         617   25-May-2019  2019    Unprovoked     USA
# 632            632         691   15-Sep-2018  2018    Unprovoked     USA
# 1040          1040        1163   29-Apr-2015  2015    Unprovoked     USA
# ...

# %%
df_us_fatal_upto2023.to_csv("/Users/emilywu/Desktop/DataLiteracy/MiniProjekt/final_shark.csv")
