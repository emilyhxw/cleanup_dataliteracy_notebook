# %%
import pandas as pd
import requests as requests
import json
import pycountry
import re
import unicodedata

# %%
df = pd.read_excel("GSAF5.xls")

# %% [markdown]
# Remove unnecessary columns

# %%
df = df.drop(["pdf", "href formula", "href", "Case Number", "Case Number.1", "original order", "Unnamed: 21", "Unnamed: 22", "Source", "State", "Time"], axis=1)

# %% [markdown]
# Filter valid Types

# %%
df = df[df['Type'].isin(["Unprovoked", "Provoked", "Watercraft" , "Air", "Sea Disaster"])]

# %% [markdown]
# Remove rows without Location or Country or Year given

# %%
df = df.dropna(subset=["Location", "Country", "Year"])

# %% [markdown]
# Trim data to only be between 2000 and 2026

# %%
df = df[df["Year"] >= 2000]
df["Year"] = pd.to_numeric(df["Year"], downcast='integer', errors='coerce')

# %%
display(df)
df.count()
# Out:
#                       Date  Year        Type            Country  \
# 0             10th January  2026  Unprovoked          Australia
# 1              8th January  2026  Unprovoked  US Virgin Islands
# 2             3rd January   2026  Unprovoked      New Caledonia
# 3            21st December  2025  Unprovoked                USA
# 4            12th December  2025  Unprovoked                USA
# ...                    ...   ...         ...                ...
# 2808           03-Feb-2000  2000  Unprovoked        NEW ZEALAND
# 2809           01-Feb-2000  2000  Unprovoked          AUSTRALIA
# 2810  Reported 28-Jan-2000  2000  Watercraft            REUNION
# 2811           05-Jan-2000  2000  Unprovoked           THAILAND
# 2812                  2000  2000  Watercraft                USA
#
#                                                Location  \
# 0                                          Avalon Beach
# 1                                          Dorsch Beach
# 2                           Between Bourail and Moindou
# 3                            Lovers Point Pacific Grove
# 4                                          Salmon Creek
# ...                                                 ...
# 2808  Oreti Beach (reported as the 4th person bitten...
# 2809           Point Sinclair, Cactus Beach near Penong
# 2810                                       Saint Pierre
# 2811                                   Phang nga Island
# 2812                            Boca Grande, Lee County
#
#                            Activity                           Name Sex  Age  \
# 0                           Surfing                   Paul Stanton   M    ?
# 1                        Snorkeling                  Arlene Lillis   F   56
# 2                      Scuba Diving                        Unknown   M    ?
# 3                          Swimming                      Erica Fox   F   55
# 4                           Surfing                        Unknown   M    ?
# ...                             ...                            ...  ..  ...
# 2808                        Surfing                  Michael Petas   M   12
# 2809                        Surfing                  Anthony Hayes   M   26
# 2810  Canoe with 3 men onboard sank              Boulabhaï Ishmael   M  NaN
# 2811                         Diving                   Stephan Kahl   M   35
# 2812             Fishing for tarpon  boat: occupant, Terry Winters   M  NaN
#
#                                                  Injury Fatal Y/N  \
# 0                           puncture mark to left thumb         N
# 1      Left arm torn off in the attack below the elbow          Y
# 2                               Injuries to upper limbs         N
# 3     Taken by shark body recovered with multiple in...         Y
# 4                                           Hand Injury         N
# ...                                                 ...       ...
# 2808                       No injury, wetsuit punctured         N
# 2809                                        Hand bitten         N
# 2810                                              FATAL         Y
# 2811                                              FATAL         Y
# 2812         No injury to occupant; shark bit propeller         N
#
#                          Species  CountryCode     latitude     longitude
# 0                         Unknown          AU  -33.6365039   151.3290299
# 1                        Unknown           VI         None          None
# 2                         Unknown          NC         None          None
# 3               Great White Shark          US   36.6233941  -121.9066666
# 4     Suspected Great White Shark          US   45.7129025  -122.6643482
# ...                           ...         ...          ...           ...
# 2808                          NaN          NZ         None          None
# 2809              3 m [10'] shark          AU         None          None
# 2810                          NaN          RE         None          None
# 2811                          NaN          TH    9.3340302    98.3232413
# 2812             Hammerhead shark          US   26.7489586   -82.2620390
#
# [2495 rows x 15 columns]
# Date           2495
# Year           2495
# Type           2495
# Country        2495
# Location       2495
# Activity       2413
# Name           2467
# Sex            2400
# Age            1942
# Injury         2488
# Fatal Y/N      2482
# Species        1586
# CountryCode    2495
# latitude       1677
# longitude      1677
# dtype: int64

# %% [markdown]
# Fetch country codes for API that gets coordinates from locations

# %%
PLACE_TO_ALPHA2_N = {
    "US Virgin Islands": "VI",
    "Canary Islands": "ES",
    "Maldive Islands": "MV",
    "ST KITTS / NEVIS": "KN",
    "ST MARTIN": "MF",
    "ST. MARTIN": "MF",
    "ST. MAARTIN": "SX",
    "REUNION ISLAND": "RE",
    "ST HELENA, British overseas territory": "SH",
    "PALESTINIAN TERRITORIES": "PS",
    "TURKS & CAICOS": "TC",
    "AZORES": "PT",
    "UNITED ARAB EMIRATES (UAE)": "AE",
    "GRAND CAYMAN": "KY",
    "CARIBBEAN SEA": "AI",  # took iso of anguilla because it was near it
}

# %%
def get_iso_code(name):
    try:
        iso = pycountry.countries.search_fuzzy(name)
        iso = iso[0].alpha_2
    except:
        if name in PLACE_TO_ALPHA2_N:
            iso = PLACE_TO_ALPHA2_N[name]
            if iso is None:
                print(name)
    return iso

# %%
df["CountryCode"] = df["Country"].apply(get_iso_code)

# %% [markdown]
# Fetch coordinates (latitude and logitude)

# %%
def get_coordinates(location, countryCode):
    headers = {"User-Agent": "shark-attack-map/1.0 (contact: e12217684@student.tuwien.ac.at)"}
    params = {"q": f"{location}", "format": "json", "countrycodes": f"{countryCode}", "limit": 1}
    response = requests.get("https://nominatim.openstreetmap.org/search",headers=headers, params=params)
    if response.status_code == 200 and len(response.json()) != 0:
        print(response.json())
        return (response.json()[0]["lat"], response.json()[0]["lon"])
    else:
        return (None, None)

# %%
df[["latitude", "longitude"]] = df.apply(
    lambda row: get_coordinates(row["Location"], row["CountryCode"]), axis=1, result_type="expand"
)
# Out:
# [{'place_id': 19543365, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2918144, 'lat': '-33.6365039', 'lon': '151.3290299', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.32173239253715025, 'addresstype': 'suburb', 'name': 'Avalon Beach', 'display_name': 'Avalon Beach, Northern Beaches, Northern Beaches Council, New South Wales, 2107, Australia', 'boundingbox': ['-33.6432341', '-33.6142715', '151.3115063', '151.3438980']}]
# [{'place_id': 298827350, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 7037922, 'lat': '36.6233941', 'lon': '-121.9066666', 'class': 'boundary', 'type': 'protected_area', 'place_rank': 25, 'importance': 0.06671889295796139, 'addresstype': 'protected_area', 'name': 'Lovers Point - Julia Platt State Marine Reserve', 'display_name': 'Lovers Point - Julia Platt State Marine Reserve, Pacific Grove Acres, Pacific Grove, Monterey County, California, United States', 'boundingbox': ['36.6183258', '36.6285825', '-121.9179012', '-121.8963333']}]
# [{'place_id': 301411715, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 237523, 'lat': '45.7129025', 'lon': '-122.6643482', 'class': 'boundary', 'type': 'census', 'place_rank': 25, 'importance': 0.3755398895276615, 'addresstype': 'census', 'name': 'Salmon Creek', 'display_name': 'Salmon Creek, Clark County, Washington, United States', 'boundingbox': ['45.6926467', '45.7326980', '-122.7072760', '-122.6204519']}]
# [{'place_id': 23818238, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6063485, 'lat': '-31.8318000', 'lon': '152.6679000', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.16004579766536964, 'addresstype': 'locality', 'name': 'Crowdy Bay', 'display_name': 'Crowdy Bay, Mid-Coast Council, New South Wales, 2443, Australia', 'boundingbox': ['-31.8549625', '-31.7214752', '152.6569815', '152.8052123']}]
# [{'place_id': 23818238, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6063485, 'lat': '-31.8318000', 'lon': '152.6679000', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.16004579766536964, 'addresstype': 'locality', 'name': 'Crowdy Bay', 'display_name': 'Crowdy Bay, Mid-Coast Council, New South Wales, 2443, Australia', 'boundingbox': ['-31.8549625', '-31.7214752', '152.6569815', '152.8052123']}]
# [{'place_id': 281493095, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 71239043, 'lat': '28.6118222', 'lon': '-95.9400871', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10667666666666664, 'addresstype': 'beach', 'name': 'Matagorda Beach', 'display_name': 'Matagorda Beach, Matagorda County, Texas, United States', 'boundingbox': ['28.5947721', '28.6284751', '-95.9811979', '-95.8981817']}]
# [{'place_id': 118904, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 836546428, 'lat': '-14.0429030', 'lon': '-171.4756963', 'class': 'building', 'type': 'yes', 'place_rank': 30, 'importance': 4.0000762951049326e-05, 'addresstype': 'building', 'name': 'Aga Reef Resort', 'display_name': 'Aga Reef Resort, Main South Coast Road, Lalomanu, Ātua, Sāmoa', 'boundingbox': ['-14.0430380', '-14.0427790', '-171.4758439', '-171.4755487']}]
# [{'place_id': 24509708, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 243032498, 'lat': '-10.5763109', 'lon': '142.2094493', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.05338105516136412, 'addresstype': 'road', 'name': 'Cook Esplanade', 'display_name': 'Cook Esplanade, Thursday Island, Torres Shire, Queensland, 4875, Australia', 'boundingbox': ['-10.5774193', '-10.5762918', '142.2076884', '142.2109522']}]
# [{'place_id': 17492247, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2110130, 'lat': '-35.8182635', 'lon': '137.1566125', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.5020362661484773, 'addresstype': 'island', 'name': 'Kangaroo Island', 'display_name': 'Kangaroo Island, Kangaroo Island Council, South Australia, Australia', 'boundingbox': ['-36.0753153', '-35.5611880', '136.5329419', '138.1349059']}]
# [{'place_id': 349756971, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 821472035, 'lat': '55.5481127', 'lon': '-133.2923757', 'class': 'place', 'type': 'islet', 'place_rank': 20, 'importance': 0.1333433333333333, 'addresstype': 'islet', 'name': 'Catalina Island', 'display_name': 'Catalina Island, Unorganized Borough, Alaska, United States', 'boundingbox': ['55.5468026', '55.5494279', '-133.2964232', '-133.2884920']}]
# [{'place_id': 283798397, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 11787037, 'lat': '5.5128003', 'lon': '-87.0936865', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.488762755355946, 'addresstype': 'island', 'name': 'Isla del Coco', 'display_name': 'Isla del Coco, Puntarenas, 60110, Costa Rica', 'boundingbox': ['5.5126841', '5.5129271', '-87.0938426', '-87.0935369']}]
# [{'place_id': 19507442, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 199301883, 'lat': '-33.7427559', 'lon': '151.3181262', 'class': 'natural', 'type': 'bare_rock', 'place_rank': 22, 'importance': 0.22898814784265079, 'addresstype': 'bare_rock', 'name': 'Long Reef', 'display_name': 'Long Reef, Collaroy, Sydney, Northern Beaches Council, New South Wales, 2097, Australia', 'boundingbox': ['-33.7445207', '-33.7409770', '151.3121866', '151.3210659']}]
# [{'place_id': 281447333, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1560526, 'lat': '29.3872254', 'lon': '-94.9927360', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.5981904824751765, 'addresstype': 'county', 'name': 'Galveston County', 'display_name': 'Galveston County, Texas, United States', 'boundingbox': ['28.9963439', '29.5982641', '-95.2330810', '-94.3662785']}]
# [{'place_id': 24008313, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6069746, 'lat': '-28.3309421', 'lon': '153.5701894', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.1600375013351644, 'addresstype': 'suburb', 'name': 'Cabarita Beach', 'display_name': 'Cabarita Beach, Tweed Shire Council, New South Wales, 2488, Australia', 'boundingbox': ['-28.3551902', '-28.3173046', '153.5683598', '153.5782236']}]
# [{'place_id': 18574359, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 129047427, 'lat': '-36.7132712', 'lon': '149.9786550', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10671620431830317, 'addresstype': 'beach', 'name': 'Tathra Beach', 'display_name': 'Tathra Beach, Tathra, Bega Valley Shire Council, New South Wales, 2550, Australia', 'boundingbox': ['-36.7275365', '-36.6999254', '149.9780997', '149.9844192']}]
# [{'place_id': 17567345, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 319681498, 'lat': '-35.0316613', 'lon': '138.5179798', 'class': 'amenity', 'type': 'pub', 'place_rank': 30, 'importance': 7.489051651784569e-05, 'addresstype': 'amenity', 'name': 'Seacliff Beach Hotel', 'display_name': 'Seacliff Beach Hotel, Wheatland Street, Seacliff, Adelaide, City of Holdfast Bay, South Australia, 5049, Australia', 'boundingbox': ['-35.0317113', '-35.0316113', '138.5179298', '138.5180298']}]
# [{'place_id': 46836418, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2174816, 'lat': '39.5177731', 'lon': '2.7426040', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.3403961829631674, 'addresstype': 'beach', 'name': 'Platja de Palma', 'display_name': "Platja de Palma, s'Arenal, Ses Cadenes, Palma, Illes Balears, 07610, España", 'boundingbox': ['39.5011387', '39.5344560', '2.7209237', '2.7516427']}]
# [{'place_id': 279375994, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 119049, 'lat': '29.0258132', 'lon': '-80.9271271', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4639836382488006, 'addresstype': 'suburb', 'name': 'New Smyrna Beach', 'display_name': 'New Smyrna Beach, Volusia County, Florida, United States', 'boundingbox': ['28.9751623', '29.0836965', '-81.0427951', '-80.8674964']}]
# [{'place_id': 277613129, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 22582175, 'lat': '26.9467489', 'lon': '-77.5376103', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.1733791126878767, 'addresstype': 'island', 'name': 'Spanish Cay', 'display_name': 'Spanish Cay, North Abaco, The Bahamas', 'boundingbox': ['26.9367964', '26.9566333', '-77.5515323', '-77.5196196']}]
# [{'place_id': 279375994, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 119049, 'lat': '29.0258132', 'lon': '-80.9271271', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4639836382488006, 'addresstype': 'suburb', 'name': 'New Smyrna Beach', 'display_name': 'New Smyrna Beach, Volusia County, Florida, United States', 'boundingbox': ['28.9751623', '29.0836965', '-81.0427951', '-80.8674964']}]
# [{'place_id': 24162561, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4694393861, 'lat': '-28.3361163', 'lon': '153.5776659', 'class': 'tourism', 'type': 'viewpoint', 'place_rank': 30, 'importance': 3.750133516437045e-05, 'addresstype': 'tourism', 'name': 'Norries Headland', 'display_name': 'Norries Headland, Cabarita Hill Walking Track, Cabarita Beach, Tweed Shire Council, New South Wales, 2488, Australia', 'boundingbox': ['-28.3361663', '-28.3360663', '153.5776159', '153.5777159']}]
# [{'place_id': 395395791, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 175638, 'lat': '40.6632890', 'lon': '-73.5135890', 'class': 'boundary', 'type': 'census', 'place_rank': 25, 'importance': 0.4801322049338613, 'addresstype': 'census', 'name': 'Wantagh', 'display_name': 'Wantagh, Town of Hempstead, Nassau County, New York, 11793, United States', 'boundingbox': ['40.6308000', '40.6938350', '-73.5261480', '-73.4937870']}]
# [{'place_id': 403349560, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 7170070, 'lat': '32.1600053', 'lon': '-80.7208796', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10670416800183105, 'addresstype': 'beach', 'name': 'Coligny Beach', 'display_name': 'Coligny Beach, Coligny, Hilton Head Island, Beaufort County, South Carolina, United States', 'boundingbox': ['32.1305471', '32.1866433', '-80.7700225', '-80.7000102']}]
# [{'place_id': 317296337, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1282536210, 'lat': '32.1263371', 'lon': '-80.7851688', 'class': 'highway', 'type': 'cycleway', 'place_rank': 27, 'importance': 0.040056762798504605, 'addresstype': 'road', 'name': 'Beach Path - Marker 39', 'display_name': 'Beach Path - Marker 39, Sea Pines, Hilton Head Island, Beaufort County, South Carolina, 29928, United States', 'boundingbox': ['32.1255354', '32.1271387', '-80.7856738', '-80.7846638']}]
# [{'place_id': 281376124, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 154373727, 'lat': '26.7489586', 'lon': '-82.2620390', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.3636287825383402, 'addresstype': 'hamlet', 'name': 'Boca Grande', 'display_name': 'Boca Grande, Lee County, Florida, 33921, United States', 'boundingbox': ['26.7289586', '26.7689586', '-82.2820390', '-82.2420390']}]
# [{'place_id': 299608260, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 218110772, 'lat': '37.5504599', 'lon': '-122.5141235', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10671186160067138, 'addresstype': 'beach', 'name': 'Montara State Beach', 'display_name': 'Montara State Beach, Montara, San Mateo County, California, United States', 'boundingbox': ['37.5448706', '37.5562506', '-122.5160197', '-122.5130929']}]
# [{'place_id': 317696986, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 176832, 'lat': '33.8807280', 'lon': '-78.5122310', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.3523734535646894, 'addresstype': 'village', 'name': 'Sunset Beach', 'display_name': 'Sunset Beach, Brunswick County, North Carolina, 28468, United States', 'boundingbox': ['33.8608540', '33.9295260', '-78.5550820', '-78.4857590']}]
# [{'place_id': 17629150, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 7268502, 'lat': '-35.1500622', 'lon': '138.4698986', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.41761362192958357, 'addresstype': 'suburb', 'name': 'Port Noarlunga', 'display_name': 'Port Noarlunga, Adelaide, City of Onkaparinga, South Australia, 5167, Australia', 'boundingbox': ['-35.1648157', '-35.1424892', '138.4661198', '138.4898644']}]
# [{'place_id': 283376522, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 373442849, 'lat': '18.5146772', 'lon': '-77.7657853', 'class': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': 5.852826733801812e-05, 'addresstype': 'tourism', 'name': 'Iberostar Waves Rose Hall Beach', 'display_name': 'Iberostar Waves Rose Hall Beach, Northern Coastal Highway, Montego Bay, Saint James, Cornwall County, Jamaica', 'boundingbox': ['18.5137792', '18.5155358', '-77.7675467', '-77.7655215']}]
# [{'place_id': 28753846, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 11273406244, 'lat': '-33.9172595', 'lon': '122.5869512', 'class': 'natural', 'type': 'bay', 'place_rank': 22, 'importance': 0.10671335851071943, 'addresstype': 'bay', 'name': 'Duke of Orleans Bay', 'display_name': 'Duke of Orleans Bay, Shire Of Esperance, Western Australia, Australia', 'boundingbox': ['-33.9173095', '-33.9172095', '122.5869012', '122.5870012']}]
# [{'place_id': 276431220, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3542057599, 'lat': '25.7481370', 'lon': '-79.2826457', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.16005200045777065, 'addresstype': 'town', 'name': 'Bimini Bay', 'display_name': 'Bimini Bay, Bimini, The Bahamas', 'boundingbox': ['25.7081370', '25.7881370', '-79.3226457', '-79.2426457']}]
# [{'place_id': 276431220, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3542057599, 'lat': '25.7481370', 'lon': '-79.2826457', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.16005200045777065, 'addresstype': 'town', 'name': 'Bimini Bay', 'display_name': 'Bimini Bay, Bimini, The Bahamas', 'boundingbox': ['25.7081370', '25.7881370', '-79.3226457', '-79.2426457']}]
# [{'place_id': 28830515, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 991842440, 'lat': '-32.4211040', 'lon': '115.7483797', 'class': 'leisure', 'type': 'park', 'place_rank': 24, 'importance': 0.08005216067750054, 'addresstype': 'park', 'name': 'Shipwreck Cove', 'display_name': 'Shipwreck Cove, Golden Bay, City of Rockingham, Western Australia, Australia', 'boundingbox': ['-32.4218153', '-32.4203116', '115.7476441', '115.7489079']}]
# [{'place_id': 28690970, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 590243691, 'lat': '-34.8801321', 'lon': '118.4000174', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10671399633783472, 'addresstype': 'beach', 'name': 'Cheynes Beach', 'display_name': 'Cheynes Beach, Cheynes, City Of Albany, Western Australia, Australia', 'boundingbox': ['-34.8818429', '-34.8784147', '118.3978209', '118.4081179']}]
# [{'place_id': 31410399, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 902925041, 'lat': '-22.0531930', 'lon': '35.3243019', 'class': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': 4.0000762951049326e-05, 'addresstype': 'tourism', 'name': 'Blue Water Bay Restcamp', 'display_name': 'Blue Water Bay Restcamp, Vilankulo, Inhambane, Zona Sul, 1304, Moçambique', 'boundingbox': ['-22.0532430', '-22.0531430', '35.3242519', '35.3243519']}]
# [{'place_id': 42103618, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 3061758, 'lat': '25.5664162', 'lon': '34.0930512', 'class': 'boundary', 'type': 'administrative', 'place_rank': 8, 'importance': 0.5048867206423362, 'addresstype': 'state', 'name': 'البحر الأحمر', 'display_name': 'البحر الأحمر, مصر', 'boundingbox': ['21.9936018', '29.1387328', '31.7881142', '37.1153517']}]
# [{'place_id': 42103618, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 3061758, 'lat': '25.5664162', 'lon': '34.0930512', 'class': 'boundary', 'type': 'administrative', 'place_rank': 8, 'importance': 0.5048867206423362, 'addresstype': 'state', 'name': 'البحر الأحمر', 'display_name': 'البحر الأحمر, مصر', 'boundingbox': ['21.9936018', '29.1387328', '31.7881142', '37.1153517']}]
# [{'place_id': 233251413, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 23605444, 'lat': '8.6113005', 'lon': '98.2381667', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10671666819256884, 'addresstype': 'beach', 'name': 'Klong Ri An Beach', 'display_name': 'Klong Ri An Beach, Merlin Resort, เขาหลัก, ลำแก่น, อำเภอท้ายเหมือง, จังหวัดพังงา, 82210, ประเทศไทย', 'boundingbox': ['8.6056779', '8.6167516', '98.2368413', '98.2383805']}]
# [{'place_id': 204661, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2647558, 'lat': '-43.9175340', 'lon': '-176.1873400', 'class': 'boundary', 'type': 'administrative', 'place_rank': 8, 'importance': 0.5476586306834035, 'addresstype': 'region', 'name': 'Chatham Islands', 'display_name': 'Chatham Islands, New Zealand / Aotearoa', 'boundingbox': ['-44.6349947', '-43.3108013', '-177.2446864', '-175.5414220']}]
# [{'place_id': 235434824, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 9328389, 'lat': '3.9411571', 'lon': '73.4899280', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.41731481675100107, 'addresstype': 'island', 'name': 'Maafushi', 'display_name': 'Maafushi, މާލެ އަތޮޅު, 08090, ދިވެހިރާއްޖެ', 'boundingbox': ['3.9360544', '3.9463216', '73.4848970', '73.4944199']}]
# [{'place_id': 22948456, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 7435953, 'lat': '-20.1189023', 'lon': '148.9134288', 'class': 'boundary', 'type': 'protected_area', 'place_rank': 25, 'importance': 0.4142480582139007, 'addresstype': 'protected_area', 'name': 'Whitsunday Islands National Park', 'display_name': 'Whitsunday Islands National Park, Whitsunday Regional, Queensland, Australia', 'boundingbox': ['-20.3608151', '-20.0581993', '148.8707306', '149.1846308']}]
# [{'place_id': 280871307, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 93618985, 'lat': '27.1858831', 'lon': '-80.1607163', 'class': 'leisure', 'type': 'park', 'place_rank': 24, 'importance': 0.08003750133516438, 'addresstype': 'park', 'name': 'Bathtub Beach', 'display_name': 'Bathtub Beach, Seminole Shores, Sailfish Point, Martin County, Florida, United States', 'boundingbox': ['27.1839518', '27.1878881', '-80.1614213', '-80.1595717']}]
# [{'place_id': 286583089, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4627386, 'lat': '15.8172492', 'lon': '-87.1146935', 'class': 'boundary', 'type': 'administrative', 'place_rank': 8, 'importance': 0.4570379194678891, 'addresstype': 'state', 'name': 'Atlántida', 'display_name': 'Atlántida, Honduras', 'boundingbox': ['15.4192394', '16.2145202', '-87.8022692', '-86.3618804']}]
# [{'place_id': 278818396, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 16021004, 'lat': '28.1016898', 'lon': '-80.6481634', 'class': 'aeroway', 'type': 'aerodrome', 'place_rank': 30, 'importance': 0.38031926104134234, 'addresstype': 'aeroway', 'name': 'Melbourne Orlando International Airport', 'display_name': 'Melbourne Orlando International Airport, 1, Salem Road, Melbourne, Brevard County, Florida, 32901, United States', 'boundingbox': ['28.0928427', '28.1107264', '-80.6713311', '-80.6245644']}]
# [{'place_id': 283360300, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3767940199, 'lat': '18.4929078', 'lon': '-77.6574376', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.4002745092006496, 'addresstype': 'town', 'name': 'Falmouth', 'display_name': 'Falmouth, Trelawny, Cornwall County, Jamaica', 'boundingbox': ['18.4529078', '18.5329078', '-77.6974376', '-77.6174376']}]
# [{'place_id': 283754388, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 7287018559, 'lat': '17.5047390', 'lon': '-88.1986089', 'class': 'amenity', 'type': 'bank', 'place_rank': 30, 'importance': 5.6959639887037726e-05, 'addresstype': 'amenity', 'name': 'Central America Investment', 'display_name': 'Central America Investment, Philip Goldson Highway, University Heights, Belize City, Belize District, Belize', 'boundingbox': ['17.5046890', '17.5047890', '-88.1986589', '-88.1985589']}]
# [{'place_id': 23786410, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 189407637, 'lat': '-31.3733420', 'lon': '152.9296992', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10669536659800104, 'addresstype': 'beach', 'name': 'North Shore Beach', 'display_name': 'North Shore Beach, Limeburners Creek, Port Macquarie-Hastings Council, New South Wales, 2444, Australia', 'boundingbox': ['-31.4235238', '-31.3216310', '152.9130724', '152.9698613']}]
# [{'place_id': 278507712, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 161833682, 'lat': '29.0768191', 'lon': '-80.9176166', 'class': 'waterway', 'type': 'river', 'place_rank': 19, 'importance': 0.14670166857404435, 'addresstype': 'river', 'name': 'Ponce de Leon Inlet', 'display_name': 'Ponce de Leon Inlet, Volusia County, Florida, United States', 'boundingbox': ['29.0755537', '29.0768438', '-80.9199510', '-80.9149386']}]
# [{'place_id': 279375994, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 119049, 'lat': '29.0258132', 'lon': '-80.9271271', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4639836382488006, 'addresstype': 'suburb', 'name': 'New Smyrna Beach', 'display_name': 'New Smyrna Beach, Volusia County, Florida, United States', 'boundingbox': ['28.9751623', '29.0836965', '-81.0427951', '-80.8674964']}]
# [{'place_id': 291809546, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6587521, 'lat': '26.1036887', 'lon': '-97.1646938', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4867875020047143, 'addresstype': 'village', 'name': 'South Padre Island', 'display_name': 'South Padre Island, Cameron County, Texas, 78597, United States', 'boundingbox': ['26.0743651', '26.1725851', '-97.1822220', '-97.1568890']}]
# [{'place_id': 291809546, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6587521, 'lat': '26.1036887', 'lon': '-97.1646938', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4867875020047143, 'addresstype': 'village', 'name': 'South Padre Island', 'display_name': 'South Padre Island, Cameron County, Texas, 78597, United States', 'boundingbox': ['26.0743651', '26.1725851', '-97.1822220', '-97.1568890']}]
# [{'place_id': 291809546, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6587521, 'lat': '26.1036887', 'lon': '-97.1646938', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4867875020047143, 'addresstype': 'village', 'name': 'South Padre Island', 'display_name': 'South Padre Island, Cameron County, Texas, 78597, United States', 'boundingbox': ['26.0743651', '26.1725851', '-97.1822220', '-97.1568890']}]
# [{'place_id': 279375994, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 119049, 'lat': '29.0258132', 'lon': '-80.9271271', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4639836382488006, 'addresstype': 'suburb', 'name': 'New Smyrna Beach', 'display_name': 'New Smyrna Beach, Volusia County, Florida, United States', 'boundingbox': ['28.9751623', '29.0836965', '-81.0427951', '-80.8674964']}]
# [{'place_id': 279807636, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 153474753, 'lat': '30.2802919', 'lon': '-86.0155650', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.28340682517387616, 'addresstype': 'village', 'name': 'Rosemary Beach', 'display_name': 'Rosemary Beach, Walton County, Florida, 32461, United States', 'boundingbox': ['30.2602919', '30.3002919', '-86.0355650', '-85.9955650']}]
# [{'place_id': 279372767, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2189404, 'lat': '30.3691634', 'lon': '-87.0327139', 'class': 'natural', 'type': 'water', 'place_rank': 22, 'importance': 0.10667666666666664, 'addresstype': 'water', 'name': 'Santa Rosa Sound', 'display_name': 'Santa Rosa Sound, Gulf Breeze, Santa Rosa County, Florida, United States', 'boundingbox': ['30.3270747', '30.4110415', '-87.1836383', '-86.5868477']}]
# [{'place_id': 290965945, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 370750720, 'lat': '32.9730390', 'lon': '-117.2701334', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10669266727702752, 'addresstype': 'beach', 'name': 'Del Mar Dog Beach', 'display_name': 'Del Mar Dog Beach, Del Mar, San Diego County, California, United States', 'boundingbox': ['32.9720559', '32.9752921', '-117.2705047', '-117.2692061']}]
# [{'place_id': 281480579, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6586786, 'lat': '29.1831247', 'lon': '-94.9729396', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4639497723876786, 'addresstype': 'village', 'name': 'Jamaica Beach', 'display_name': 'Jamaica Beach, Galveston County, Texas, United States', 'boundingbox': ['29.1774633', '29.2008687', '-94.9916953', '-94.9691490']}]
# [{'place_id': 277829006, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 390137331, 'lat': '11.2150872', 'lon': '-60.7772014', 'class': 'tourism', 'type': 'hotel', 'place_rank': 30, 'importance': 4.6261539635263866e-05, 'addresstype': 'tourism', 'name': 'Turtle Beach', 'display_name': 'Turtle Beach, Shirvan Road, Black Rock, Tobago, Trinidad and Tobago', 'boundingbox': ['11.2145861', '11.2153066', '-60.7774236', '-60.7768046']}]
# [{'place_id': 284147921, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 6431713185, 'lat': '23.1028160', 'lon': '-74.9607531', 'class': 'amenity', 'type': 'restaurant', 'place_rank': 30, 'importance': 4.958800640874369e-05, 'addresstype': 'amenity', 'name': 'Lighthouse Point at Flying Fish Marina', 'display_name': 'Lighthouse Point at Flying Fish Marina, Hill Street, Scrub Hill Settlement, Long Island, The Bahamas', 'boundingbox': ['23.1027660', '23.1028660', '-74.9608031', '-74.9607031']}]
# [{'place_id': 17829084, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 339068185, 'lat': '-38.2705775', 'lon': '141.3529506', 'class': 'highway', 'type': 'path', 'place_rank': 27, 'importance': 0.04004692683298999, 'addresstype': 'road', 'name': 'Great South West Walk (beach)', 'display_name': 'Great South West Walk (beach), Mount Richmond, Shire of Glenelg, Victoria, 3305, Australia', 'boundingbox': ['-38.3264321', '-38.2231310', '141.2990057', '141.3966726']}]
# [{'place_id': 22986488, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1305188000, 'lat': '-24.8369920', 'lon': '152.4663409', 'class': 'landuse', 'type': 'residential', 'place_rank': 22, 'importance': 0.10672234302281221, 'addresstype': 'residential', 'name': 'Bargara Beach', 'display_name': 'Bargara Beach, Bargara, Bundaberg Region, Queensland, Australia', 'boundingbox': ['-24.8390156', '-24.8327449', '152.4637457', '152.4683661']}]
# [{'place_id': 230259660, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 801753319, 'lat': '19.6529015', 'lon': '73.1823697', 'class': 'waterway', 'type': 'river', 'place_rank': 19, 'importance': 0.14670666742961772, 'addresstype': 'river', 'name': 'Vaitarna River', 'display_name': 'Vaitarna River, Wada, Wada Taluka, Palghar, Maharashtra, India', 'boundingbox': ['19.6177869', '19.6760480', '73.0818117', '73.2898861']}]
# [{'place_id': 28984431, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4305896771, 'lat': '-33.9633931', 'lon': '24.9562381', 'class': 'tourism', 'type': 'attraction', 'place_rank': 30, 'importance': 4.5001144426596745e-05, 'addresstype': 'tourism', 'name': 'Papiesfontein', 'display_name': 'Papiesfontein, Cape Road, Kouga Ward 8, Kouga Local Municipality, Sarah Baartman District Municipality, Eastern Cape, 6335, South Africa', 'boundingbox': ['-33.9634431', '-33.9633431', '24.9561881', '24.9562881']}]
# [{'place_id': 349913417, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 287216568, 'lat': '20.8823591', 'lon': '-156.6877451', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10671679179064619, 'addresstype': 'beach', 'name': 'Baby Beach', 'display_name': 'Baby Beach, Mala, Lahaina, Maui County, Hawaii, United States', 'boundingbox': ['20.8801637', '20.8845301', '-156.6878560', '-156.6848889']}]
# [{'place_id': 25876520, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1278456492, 'lat': '-10.4634756', 'lon': '105.7074432', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.1067131128404669, 'addresstype': 'beach', 'name': 'Ethel Beach', 'display_name': 'Ethel Beach, Christmas Island, Shire of Christmas Island, Christmas Island, 6798, Australia', 'boundingbox': ['-10.4637310', '-10.4632167', '105.7072896', '105.7076729']}]
# [{'place_id': 23845285, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6063728, 'lat': '-31.9650000', 'lon': '152.5844444', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.16004579766536964, 'addresstype': 'locality', 'name': 'Old Bar', 'display_name': 'Old Bar, Mid-Coast Council, New South Wales, 2430, Australia', 'boundingbox': ['-31.9873762', '-31.9373677', '152.5223386', '152.6076432']}]
# [{'place_id': 28654414, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 9045918, 'lat': '-30.8285606', 'lon': '115.1884471', 'class': 'place', 'type': 'islet', 'place_rank': 20, 'importance': 0.3508056963223209, 'addresstype': 'islet', 'name': 'Wedge Island', 'display_name': 'Wedge Island, Shire Of Dandaragan, Western Australia, 6044, Australia', 'boundingbox': ['-30.8299170', '-30.8272621', '115.1874283', '115.1906033']}]
# [{'place_id': 19913515, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 983008811, 'lat': '-46.3509977', 'lon': '168.0202689', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.3380507607701352, 'addresstype': 'town', 'name': 'Riverton / Aparima', 'display_name': 'Riverton / Aparima, Oraka Aparima Community, Southland District, Southland, 9822, New Zealand / Aotearoa', 'boundingbox': ['-46.3909977', '-46.3109977', '167.9802689', '168.0602689']}]
# [{'place_id': 408131881, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 12876271050, 'lat': '-34.0071818', 'lon': '151.2163091', 'class': 'amenity', 'type': 'cafe', 'place_rank': 30, 'importance': 8.246051728079679e-05, 'addresstype': 'amenity', 'name': '1770', 'display_name': '1770, Captain Cook Drive, Kurnell, Sutherland Shire, Sydney, Sutherland Shire Council, New South Wales, 2231, Australia', 'boundingbox': ['-34.0072318', '-34.0071318', '151.2162591', '151.2163591']}]
# [{'place_id': 277598115, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 302568524, 'lat': '25.0770578', 'lon': '-77.4102421', 'class': 'leisure', 'type': 'beach_resort', 'place_rank': 30, 'importance': 6.775387197676078e-05, 'addresstype': 'leisure', 'name': 'Sandals Royal Bahamian Spa Resort & Offshore Island', 'display_name': 'Sandals Royal Bahamian Spa Resort & Offshore Island, Cable Beach Manor, Westward Villas, Nassau, New Providence, The Bahamas', 'boundingbox': ['25.0759360', '25.0784818', '-77.4114791', '-77.4090132']}]
# [{'place_id': 285209171, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 144488623, 'lat': '19.2231994', 'lon': '-104.7046088', 'class': 'landuse', 'type': 'residential', 'place_rank': 22, 'importance': 0.10671601052872508, 'addresstype': 'residential', 'name': 'San Patricio / Melaque', 'display_name': 'San Patricio / Melaque, Melaque, Cihuatlán, Región Costa Sur, Jalisco, México', 'boundingbox': ['19.2162066', '19.2301482', '-104.7150721', '-104.6929016']}]
# [{'place_id': 17629150, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 7268502, 'lat': '-35.1500622', 'lon': '138.4698986', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.41761362192958357, 'addresstype': 'suburb', 'name': 'Port Noarlunga', 'display_name': 'Port Noarlunga, Adelaide, City of Onkaparinga, South Australia, 5167, Australia', 'boundingbox': ['-35.1648157', '-35.1424892', '138.4661198', '138.4898644']}]
# [{'place_id': 282222788, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1217010, 'lat': '26.8815475', 'lon': '-80.0539253', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.1867188136110475, 'addresstype': 'village', 'name': 'Juno Beach', 'display_name': 'Juno Beach, Palm Beach County, Florida, United States', 'boundingbox': ['26.8560410', '26.8937112', '-80.0734584', '-80.0422620']}]
# [{'place_id': 28756355, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 648200363, 'lat': '-34.2160354', 'lon': '115.0205337', 'class': 'place', 'type': 'islet', 'place_rank': 20, 'importance': 0.13338008926527808, 'addresstype': 'islet', 'name': 'Peak Island', 'display_name': 'Peak Island, Shire Of Augusta Margaret River, Western Australia, Australia', 'boundingbox': ['-34.2162251', '-34.2158437', '115.0199941', '115.0208472']}]
# [{'place_id': 17479759, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 7109329, 'lat': '-32.7380424', 'lon': '134.6157973', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.3636287825383402, 'addresstype': 'county', 'name': 'The District Council of Streaky Bay', 'display_name': 'The District Council of Streaky Bay, South Australia, Australia', 'boundingbox': ['-33.2451661', '-32.2310052', '133.9651259', '135.1366839']}]
# [{'place_id': 28775649, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3020491037, 'lat': '-33.8913551', 'lon': '122.7908335', 'class': 'natural', 'type': 'bay', 'place_rank': 22, 'importance': 0.10671335851071943, 'addresstype': 'bay', 'name': 'Alexander Bay', 'display_name': 'Alexander Bay, Shire Of Esperance, Western Australia, Australia', 'boundingbox': ['-33.8914051', '-33.8913051', '122.7907835', '122.7908835']}]
# [{'place_id': 283330840, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 12446040, 'lat': '17.9026253', 'lon': '-87.9817932', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.17337833447775997, 'addresstype': 'island', 'name': 'South Ambergris Caye', 'display_name': 'South Ambergris Caye, San Pedro Town, Belize District, Belize', 'boundingbox': ['17.8747223', '17.9305336', '-88.0279340', '-87.9566912']}]
# [{'place_id': 349785981, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 368391200, 'lat': '22.2100000', 'lon': '-159.5091667', 'class': 'natural', 'type': 'bay', 'place_rank': 22, 'importance': 0.24830372814560323, 'addresstype': 'bay', 'name': 'Hanalei Bay', 'display_name': 'Hanalei Bay, Hanalei, Kauaʻi County, Hawaii, 96714, United States', 'boundingbox': ['22.2099500', '22.2100500', '-159.5092167', '-159.5091167']}]
# [{'place_id': 350124516, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 119161, 'lat': '20.9024570', 'lon': '-156.3727211', 'class': 'place', 'type': 'locality', 'place_rank': 25, 'importance': 0.3567097398182398, 'addresstype': 'village', 'name': 'Paia', 'display_name': 'Paia, Maui County, Hawaii, 96779, United States', 'boundingbox': ['20.8794700', '20.9386130', '-156.3953960', '-156.3486761']}]
# [{'place_id': 17953981, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6719077, 'lat': '-37.4818511', 'lon': '140.0106789', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.32850614987876553, 'addresstype': 'town', 'name': 'Beachport', 'display_name': 'Beachport, Wattle Range Council, South Australia, 5280, Australia', 'boundingbox': ['-37.5373630', '-37.3442475', '139.9203849', '140.1809533']}]
# [{'place_id': 296611613, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 275414187, 'lat': '37.9653927', 'lon': '-122.7895068', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10667666666666664, 'addresstype': 'beach', 'name': 'Wildcat Beach', 'display_name': 'Wildcat Beach, Marin County, California, United States', 'boundingbox': ['37.9513830', '37.9792249', '-122.8000253', '-122.7827366']}]
# [{'place_id': 317138953, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 193842, 'lat': '33.6956461', 'lon': '-78.8900409', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.5261775093357874, 'addresstype': 'city', 'name': 'Myrtle Beach', 'display_name': 'Myrtle Beach, Horry County, South Carolina, United States', 'boundingbox': ['33.6473768', '33.7912550', '-78.9780240', '-78.7854686']}]
# [{'place_id': 41990029, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 27043265, 'lat': '28.4963633', 'lon': '34.5145652', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.4568218656566384, 'addresstype': 'city', 'name': 'دهب', 'display_name': 'دهب, جنوب سيناء, 45214, مصر', 'boundingbox': ['28.3363633', '28.6563633', '34.3545652', '34.6745652']}]
# [{'place_id': 279225625, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1216825, 'lat': '28.1760051', 'lon': '-80.5904623', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.43599268008861497, 'addresstype': 'village', 'name': 'Satellite Beach', 'display_name': 'Satellite Beach, Brevard County, Florida, 32937, United States', 'boundingbox': ['28.1574957', '28.1979835', '-80.6148639', '-80.5847991']}]
# [{'place_id': 276117126, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1217234, 'lat': '29.0963729', 'lon': '-80.9369983', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4287524734837362, 'addresstype': 'village', 'name': 'Ponce Inlet', 'display_name': 'Ponce Inlet, Volusia County, Florida, United States', 'boundingbox': ['29.0704560', '29.1221764', '-80.9753073', '-80.9197278']}]
# [{'place_id': 276117126, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1217234, 'lat': '29.0963729', 'lon': '-80.9369983', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4287524734837362, 'addresstype': 'village', 'name': 'Ponce Inlet', 'display_name': 'Ponce Inlet, Volusia County, Florida, United States', 'boundingbox': ['29.0704560', '29.1221764', '-80.9753073', '-80.9197278']}]
# [{'place_id': 23935564, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 173070325, 'lat': '-31.5222063', 'lon': '152.8840198', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10671646219577323, 'addresstype': 'beach', 'name': 'Lighthouse Beach', 'display_name': 'Lighthouse Beach, Port Macquarie, Port Macquarie-Hastings Council, New South Wales, 2444, Australia', 'boundingbox': ['-31.5647768', '-31.4796240', '152.8501220', '152.9292578']}]
# [{'place_id': 317312828, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 179061, 'lat': '33.9122506', 'lon': '-78.1116284', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.39005097060730937, 'addresstype': 'town', 'name': 'Oak Island', 'display_name': 'Oak Island, Brunswick County, North Carolina, 28465, United States', 'boundingbox': ['33.9013160', '33.9411570', '-78.2368730', '-78.0573010']}]
# [{'place_id': 298990111, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 358772514, 'lat': '37.2369952', 'lon': '-122.4159993', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10667666666666664, 'addresstype': 'beach', 'name': 'Pebble Beach', 'display_name': 'Pebble Beach, San Mateo County, California, 94060, United States', 'boundingbox': ['37.2369452', '37.2370452', '-122.4160493', '-122.4159493']}]
# [{'place_id': 114629, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1324332732, 'lat': '-13.6169300', 'lon': '-172.2025415', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.14670416800183103, 'addresstype': 'village', 'name': 'Lano', 'display_name': 'Lano, Faʻasaleleaga, Sāmoa', 'boundingbox': ['-13.6288880', '-13.6075084', '-172.2616146', '-172.1937148']}]
# [{'place_id': 331334891, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 170550, 'lat': '40.9012101', 'lon': '-74.5143232', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4141856465713948, 'addresstype': 'village', 'name': 'Rockaway', 'display_name': 'Rockaway, Morris County, New Jersey, United States', 'boundingbox': ['40.8834490', '40.9117640', '-74.5364110', '-74.4969050']}]
# [{'place_id': 279375994, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 119049, 'lat': '29.0258132', 'lon': '-80.9271271', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4639836382488006, 'addresstype': 'suburb', 'name': 'New Smyrna Beach', 'display_name': 'New Smyrna Beach, Volusia County, Florida, United States', 'boundingbox': ['28.9751623', '29.0836965', '-81.0427951', '-80.8674964']}]
# [{'place_id': 281827614, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 33534731, 'lat': '27.5293620', 'lon': '-82.7324345', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.421937116997898, 'addresstype': 'village', 'name': 'Anna Maria island', 'display_name': 'Anna Maria island, Manatee County, Florida, 34216, United States', 'boundingbox': ['27.5193777', '27.5393403', '-82.7465238', '-82.7195536']}]
# [{'place_id': 277449989, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 369137717, 'lat': '27.6886419', 'lon': '-82.5723193', 'class': 'natural', 'type': 'bay', 'place_rank': 22, 'importance': 0.476846016000311, 'addresstype': 'bay', 'name': 'Tampa Bay', 'display_name': 'Tampa Bay, Hillsborough County, Florida, United States', 'boundingbox': ['27.6885919', '27.6886919', '-82.5723693', '-82.5722693']}]
# [{'place_id': 414941648, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 320346809, 'lat': '-33.9843554', 'lon': '114.9900566', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.0447024495918557, 'addresstype': 'beach', 'name': 'Gnarabup Beach', 'display_name': 'Gnarabup Beach, Prevelly, Shire Of Augusta Margaret River, Western Australia, 6285, Australia', 'boundingbox': ['-33.9908534', '-33.9779094', '114.9879943', '114.9914350']}]
# ...
# [{'place_id': 402479661, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 117524, 'lat': '29.8946952', 'lon': '-81.3145395', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.5608159507405109, 'addresstype': 'town', 'name': 'Saint Augustine', 'display_name': 'Saint Augustine, Saint Johns County, Florida, 32084, United States', 'boundingbox': ['29.8463226', '29.9555444', '-81.3445902', '-81.2657081']}]
# [{'place_id': 32933249, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 137119976, 'lat': '-6.7690817', 'lon': '39.2821865', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10673196993972683, 'addresstype': 'beach', 'name': 'Coco Beach', 'display_name': 'Coco Beach, Msasani, Kinondoni Municipal, Dar es-Salaam, Coastal Zone, Tanzania', 'boundingbox': ['-6.7756158', '-6.7621035', '39.2816125', '39.2841750']}]
# [{'place_id': 279405998, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 119049, 'lat': '29.0258132', 'lon': '-80.9271271', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4639836382488006, 'addresstype': 'suburb', 'name': 'New Smyrna Beach', 'display_name': 'New Smyrna Beach, Volusia County, Florida, United States', 'boundingbox': ['28.9751623', '29.0836965', '-81.0427951', '-80.8674964']}]
# [{'place_id': 283340249, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 119068, 'lat': '24.6892686', 'lon': '-81.3689004', 'class': 'boundary', 'type': 'census', 'place_rank': 25, 'importance': 0.4168137108705858, 'addresstype': 'locality', 'name': 'Big Pine Key', 'display_name': 'Big Pine Key, Monroe County, Florida, 33043, United States', 'boundingbox': ['24.6329950', '24.7455410', '-81.4021170', '-81.3279365']}]
# [{'place_id': 316064211, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6724977, 'lat': '33.9135061', 'lon': '-78.3038892', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.3432915720398012, 'addresstype': 'village', 'name': 'Holden Beach', 'display_name': 'Holden Beach, Brunswick County, North Carolina, United States', 'boundingbox': ['33.8999143', '33.9207009', '-78.3843078', '-78.2373066']}]
# [{'place_id': 29321848, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2789475, 'lat': '-32.9757754', 'lon': '27.9268792', 'class': 'natural', 'type': 'water', 'place_rank': 22, 'importance': 0.22742205121143227, 'addresstype': 'water', 'name': 'Nahoon River', 'display_name': 'Nahoon River, Buffalo City Ward 4, East London, Buffalo City Metropolitan Municipality, Eastern Cape, South Africa', 'boundingbox': ['-32.9868879', '-32.9645733', '27.9155247', '27.9525474']}]
# [{'place_id': 29307003, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 582360679, 'lat': '-34.0290205', 'lon': '25.7006801', 'class': 'man_made', 'type': 'lighthouse', 'place_rank': 30, 'importance': 6.471427481493885e-05, 'addresstype': 'man_made', 'name': 'Cape Recife', 'display_name': 'Cape Recife, Marine Drive, Noordhoek, Nelson Mandela Bay Ward 1, Gqeberha (Port Elizabeth), Nelson Mandela Bay Metropolitan Municipality, Eastern Cape, 6031, South Africa', 'boundingbox': ['-34.0290449', '-34.0289919', '25.7006481', '25.7007120']}]
# [{'place_id': 279340875, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 117945, 'lat': '29.2108147', 'lon': '-81.0228331', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.5804458673846268, 'addresstype': 'city', 'name': 'Daytona Beach', 'display_name': 'Daytona Beach, Volusia County, Florida, United States', 'boundingbox': ['29.1288338', '29.2687678', '-81.2115407', '-80.9830946']}]
# [{'place_id': 279266451, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 997747428, 'lat': '29.2985625', 'lon': '-81.0510685', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.05338637750820169, 'addresstype': 'road', 'name': 'Neptune Avenue', 'display_name': 'Neptune Avenue, Ormond Beach, Volusia County, Florida, 32176, United States', 'boundingbox': ['29.2981290', '29.2989960', '-81.0522180', '-81.0499190']}]
# [{'place_id': 289979788, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 356712538, 'lat': '27.7394760', 'lon': '-97.1316551', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.3065685497365947, 'addresstype': 'island', 'name': 'Mustang Island', 'display_name': 'Mustang Island, Corpus Christi, Nueces County, Texas, United States', 'boundingbox': ['27.4194760', '28.0594760', '-97.4516551', '-96.8116551']}]
# [{'place_id': 317479159, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 12020553955, 'lat': '36.2614737', 'lon': '-75.7888754', 'class': 'place', 'type': 'neighbourhood', 'place_rank': 20, 'importance': 0.13337833447775996, 'addresstype': 'neighbourhood', 'name': 'Pine Island', 'display_name': 'Pine Island, Corolla, Currituck County, North Carolina, United States', 'boundingbox': ['36.2514737', '36.2714737', '-75.7988754', '-75.7788754']}]
# [{'place_id': 279340875, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 117945, 'lat': '29.2108147', 'lon': '-81.0228331', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.5804458673846268, 'addresstype': 'city', 'name': 'Daytona Beach', 'display_name': 'Daytona Beach, Volusia County, Florida, United States', 'boundingbox': ['29.1288338', '29.2687678', '-81.2115407', '-80.9830946']}]
# [{'place_id': 279393113, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 456255004, 'lat': '29.0682964', 'lon': '-80.9136984', 'class': 'leisure', 'type': 'park', 'place_rank': 24, 'importance': 0.0800529633020523, 'addresstype': 'park', 'name': 'Smyrna Dunes Park', 'display_name': 'Smyrna Dunes Park, New Smyrna Beach, Volusia County, Florida, United States', 'boundingbox': ['29.0630951', '29.0735409', '-80.9186454', '-80.9075867']}]
# [{'place_id': 279393113, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 456255004, 'lat': '29.0682964', 'lon': '-80.9136984', 'class': 'leisure', 'type': 'park', 'place_rank': 24, 'importance': 0.0800529633020523, 'addresstype': 'park', 'name': 'Smyrna Dunes Park', 'display_name': 'Smyrna Dunes Park, New Smyrna Beach, Volusia County, Florida, United States', 'boundingbox': ['29.0630951', '29.0735409', '-80.9186454', '-80.9075867']}]
# [{'place_id': 32933249, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 137119976, 'lat': '-6.7690817', 'lon': '39.2821865', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10673196993972683, 'addresstype': 'beach', 'name': 'Coco Beach', 'display_name': 'Coco Beach, Msasani, Kinondoni Municipal, Dar es-Salaam, Coastal Zone, Tanzania', 'boundingbox': ['-6.7756158', '-6.7621035', '39.2816125', '39.2841750']}]
# [{'place_id': 420377197, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1442785005, 'lat': '-37.6972669', 'lon': '176.2848286', 'class': 'place', 'type': 'suburb', 'place_rank': 19, 'importance': 0.3240001143151359, 'addresstype': 'suburb', 'name': 'Papamoa Beach', 'display_name': 'Papamoa Beach, Papamoa, Tauranga City, Bay of Plenty, 3118, New Zealand / Aotearoa', 'boundingbox': ['-37.7197636', '-37.6760682', '176.2372642', '176.3430723']}]
# [{'place_id': 279043527, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 11374275, 'lat': '29.2848639', 'lon': '-81.0398353', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.05336833524071104, 'addresstype': 'road', 'name': 'Seminole Avenue', 'display_name': 'Seminole Avenue, Ellinor Village, Ormond Beach, Volusia County, Florida, 32176, United States', 'boundingbox': ['29.2837784', '29.2859877', '-81.0425772', '-81.0371143']}]
# [{'place_id': 280358082, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2191869, 'lat': '30.3880640', 'lon': '-87.1876779', 'class': 'natural', 'type': 'water', 'place_rank': 22, 'importance': 0.10669536659800104, 'addresstype': 'water', 'name': 'Pensacola Bay', 'display_name': 'Pensacola Bay, Gulf Breeze, Santa Rosa County, Florida, United States', 'boundingbox': ['30.3199615', '30.4563493', '-87.3183136', '-87.0708173']}]
# [{'place_id': 278265951, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 110229, 'lat': '30.2711224', 'lon': '-87.6893826', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4629587721493126, 'addresstype': 'town', 'name': 'Gulf Shores', 'display_name': 'Gulf Shores, Baldwin County, Alabama, 36542, United States', 'boundingbox': ['30.2302298', '30.3339552', '-87.8017570', '-87.6231979']}]
# [{'place_id': 278265951, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 110229, 'lat': '30.2711224', 'lon': '-87.6893826', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4629587721493126, 'addresstype': 'town', 'name': 'Gulf Shores', 'display_name': 'Gulf Shores, Baldwin County, Alabama, 36542, United States', 'boundingbox': ['30.2302298', '30.3339552', '-87.8017570', '-87.6231979']}]
# [{'place_id': 279135170, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 11375713, 'lat': '29.0093124', 'lon': '-80.8786906', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.05337333409628439, 'addresstype': 'road', 'name': '27th Avenue', 'display_name': '27th Avenue, New Smyrna Beach, Volusia County, Florida, 32169, United States', 'boundingbox': ['29.0090465', '29.0095865', '-80.8793013', '-80.8780835']}]
# [{'place_id': 279812327, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2189404, 'lat': '30.3691634', 'lon': '-87.0327139', 'class': 'natural', 'type': 'water', 'place_rank': 22, 'importance': 0.10667666666666664, 'addresstype': 'water', 'name': 'Santa Rosa Sound', 'display_name': 'Santa Rosa Sound, Gulf Breeze, Santa Rosa County, Florida, United States', 'boundingbox': ['30.3270747', '30.4110415', '-87.1836383', '-86.5868477']}]
# [{'place_id': 23870220, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 11675454, 'lat': '-27.9787768', 'lon': '153.4271228', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.3227145168810713, 'addresstype': 'suburb', 'name': 'Main Beach', 'display_name': 'Main Beach, Gold Coast City, Queensland, 4217, Australia', 'boundingbox': ['-27.9896133', '-27.9287720', '153.4091410', '153.4336856']}]
# [{'place_id': 280335854, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1217010, 'lat': '26.8815475', 'lon': '-80.0539253', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.1867188136110475, 'addresstype': 'village', 'name': 'Juno Beach', 'display_name': 'Juno Beach, Palm Beach County, Florida, United States', 'boundingbox': ['26.8560410', '26.8937112', '-80.0734584', '-80.0422620']}]
# [{'place_id': 281234337, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 154385148, 'lat': '27.9462734', 'lon': '-80.4970188', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.2976383631796269, 'addresstype': 'hamlet', 'name': 'Floridana Beach', 'display_name': 'Floridana Beach, Brevard County, Florida, United States', 'boundingbox': ['27.9262734', '27.9662734', '-80.5170188', '-80.4770188']}]
# [{'place_id': 19670886, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2214248, 'lat': '-33.8215352', 'lon': '151.0860852', 'class': 'waterway', 'type': 'river', 'place_rank': 18, 'importance': 0.45180049976750014, 'addresstype': 'river', 'name': 'Parramatta River', 'display_name': 'Parramatta River, Sydney, City of Parramatta Council, New South Wales, 2150, Australia', 'boundingbox': ['-33.8467854', '-33.7987442', '150.9958928', '151.1869440']}]
# [{'place_id': 19670886, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2214248, 'lat': '-33.8215352', 'lon': '151.0860852', 'class': 'waterway', 'type': 'river', 'place_rank': 18, 'importance': 0.45180049976750014, 'addresstype': 'river', 'name': 'Parramatta River', 'display_name': 'Parramatta River, Sydney, City of Parramatta Council, New South Wales, 2150, Australia', 'boundingbox': ['-33.8467854', '-33.7987442', '150.9958928', '151.1869440']}]
# [{'place_id': 282412282, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 117921, 'lat': '26.7843430', 'lon': '-80.0650293', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.47951184868579083, 'addresstype': 'suburb', 'name': 'Riviera Beach', 'display_name': 'Riviera Beach, Palm Beach County, Florida, 33404, United States', 'boundingbox': ['26.7621928', '26.8149390', '-80.1194650', '-80.0301770']}]
# [{'place_id': 29583291, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 11445984695, 'lat': '-34.8111916', 'lon': '20.0369060', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.14671021057450212, 'addresstype': 'village', 'name': 'Struis Bay', 'display_name': 'Struis Bay, Cape Agulhas Local Municipality, Western Cape, 7285, South Africa', 'boundingbox': ['-34.8311916', '-34.7911916', '20.0169060', '20.0569060']}]
# [{'place_id': 405411978, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 241700289, 'lat': '9.3340302', 'lon': '98.3232413', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.24005000152590217, 'addresstype': 'islet', 'name': 'Ko Khai Yai', 'display_name': 'Ko Khai Yai, จังหวัดพังงา, ประเทศไทย', 'boundingbox': ['9.3308679', '9.3373067', '98.3210893', '98.3254723']}]
# [{'place_id': 282313846, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 154373727, 'lat': '26.7489586', 'lon': '-82.2620390', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.3636287825383402, 'addresstype': 'hamlet', 'name': 'Boca Grande', 'display_name': 'Boca Grande, Lee County, Florida, 33921, United States', 'boundingbox': ['26.7289586', '26.7689586', '-82.2820390', '-82.2420390']}]

# %% [markdown]
# 1. Clean up of locations: removing special symbols, between, off, etc

# %%
# Regex-Bausteine
RE_PARENS = re.compile(r"\([^)]*\)")
RE_BETWEEN = re.compile(r"\bbetween\s+(?P<a>.+?)\s+(?:and|&)\s+(?P<b>.+)\b", re.IGNORECASE)
RE_CHANNEL_BETWEEN = re.compile(r"\bchannel\s+between\s+(?P<a>.+?)\s+(?:and|&)\s+(?P<b>.+)\b", re.IGNORECASE)
RE_OFF = re.compile(r"\b(?:\d+\s*(?:nm|km|miles?)\s+)?off\s+(?P<place>.+)\b", re.IGNORECASE)

# Distanzen/“about 500 km (310 miles)” usw.
RE_DISTANCE = re.compile(r"\babout\s+\d+.*?$|\b\d+\s*(?:km|m|nm|miles?)\b", re.IGNORECASE)

# Richtungsausdrücke (macht’s simpler)
RE_DIRECTION_OF = re.compile(r"\b(north|south|east|west)\s+of\s+", re.IGNORECASE)

def simplify_location(loc: str) -> str:
    if not isinstance(loc, str) or not loc.strip():
        return ""

    s = loc.strip()

    # 1) Klammern entfernen
    s = RE_PARENS.sub("", s)

    # 2) komische Quotes normalisieren/entfernen
    s = s.replace("“", '"').replace("”", '"').replace("’", "'").replace("`", "'")

    # 3) "between A and B" => A
    m = RE_CHANNEL_BETWEEN.search(s)
    if m:
        s = m.group("a")
    else:
        m = RE_BETWEEN.search(s)
        if m:
            s = m.group("a")

    # 4) "off X" => X (auch "70 miles off Pensacola")
    m = RE_OFF.search(s)
    if m:
        s = m.group("place")

    # 5) "north of X" => X (wir wollen was Geocodable)
    s = RE_DIRECTION_OF.sub("", s)

    # 6) "near Y" => Y (nimmt den Teil nach dem letzten 'near')
    if re.search(r"\bnear\b", s, flags=re.IGNORECASE):
        s = re.split(r"\bnear\b", s, flags=re.IGNORECASE)[-1]

    # 7) Distanzen/“about …” raus
    s = RE_DISTANCE.sub("", s)

    # 8) Fragezeichen/seltsame Satzzeichen raus
    s = s.replace("?", "").replace("!", "").replace(";", "").replace("/", "")
    s = s.replace('"', "").replace("'", "")  # Apostrophe/Quotes komplett raus (einfachster Weg)

    # 9) Mehrfachspaces/Kommas normalisieren
    s = re.sub(r"\s+", " ", s).strip()
    s = s.strip(" ,.-")

    # 10) optional: nur erster Teil vor Komma (sehr “einfacher” fallback)
    #    (wenn du lieber mehr Kontext behalten willst, kommentier die nächste Zeile aus)
    if "," in s:
        s = s.split(",")[0].strip()

    return s

# %%
coord_notfound = df.loc[df["latitude"].isna()].copy()
coord_notfound["cleaned_location"] = coord_notfound["Location"].apply(simplify_location)

# %%
display(coord_notfound)
coord_notfound.count()
# Out:
#                       Date  Year        Type            Country  \
# 1              8th January  2026  Unprovoked  US Virgin Islands
# 2             3rd January   2026  Unprovoked      New Caledonia
# 5             9th December  2025    Provoked                USA
# 8            10th November  2025  Unprovoked          Australia
# 9             9th November  2025  Unprovoked   French Polynesia
# ...                    ...   ...         ...                ...
# 2804              Mar-2000  2000  Unprovoked                USA
# 2807           14-Feb-2000  2000    Provoked            ENGLAND
# 2808           03-Feb-2000  2000  Unprovoked        NEW ZEALAND
# 2809           01-Feb-2000  2000  Unprovoked          AUSTRALIA
# 2810  Reported 28-Jan-2000  2000  Watercraft            REUNION
#
#                                                Location  \
# 1                                          Dorsch Beach
# 2                           Between Bourail and Moindou
# 5                                      Ka'alu"alu Beach
# 8                          Prevelly Beach Magaret River
# 9                                           Hakahau Bay
# ...                                                 ...
# 2804                  Midnight Lump (38 miles offshore)
# 2807                  The Fountain Pub in Tenbury Wells
# 2808  Oreti Beach (reported as the 4th person bitten...
# 2809           Point Sinclair, Cactus Beach near Penong
# 2810                                       Saint Pierre
#
#                               Activity                    Name Sex  Age  \
# 1                           Snorkeling           Arlene Lillis   F   56
# 2                         Scuba Diving                 Unknown   M    ?
# 5                Freeing trapped shark  Josiah Kaimani Ventura   M   24
# 8                        Foil Boarding           Andy McDonald   M   61
# 9                             Swimming    Not stated (Dentist)   M   40
# ...                                ...                     ...  ..  ...
# 2804                      Spearfishing             Kurt Bickel   M   39
# 2807  Feeding prawns to captive sharks      Paul Smith, a chef   M  NaN
# 2808                           Surfing           Michael Petas   M   12
# 2809                           Surfing           Anthony Hayes   M   26
# 2810     Canoe with 3 men onboard sank       Boulabhaï Ishmael   M  NaN
#
#                                                 Injury Fatal Y/N  \
# 1     Left arm torn off in the attack below the elbow          Y
# 2                              Injuries to upper limbs         N
# 5                                 Bite wounds to thigh         N
# 8                                    No Injury to self         N
# 9                                   Deep Gash to bicep         N
# ...                                                ...       ...
# 2804              No injury to diver, speargun damaged         N
# 2807                  Fingers bitten PROVOKED INCIDENT         N
# 2808                      No injury, wetsuit punctured         N
# 2809                                       Hand bitten         N
# 2810                                             FATAL         Y
#
#                                                Species  CountryCode  \
# 1                                              Unknown           VI
# 2                                               Unknown          NC
# 5                                  Black Tip Reef Shark          US
# 8                                     Great White Shark          AU
# 9                                              3m shark          PF
# ...                                                 ...         ...
# 2804    Shortfin mako shark, 3 m to 3.4 m [10' to 11']           US
# 2807  Miami, a 60 cm blacktip  shark and two 60 cm b...          GB
# 2808                                                NaN          NZ
# 2809                                    3 m [10'] shark          AU
# 2810                                                NaN          RE
#
#          latitude    longitude                   cleaned_location
# 1            None         None                       Dorsch Beach
# 2            None         None                            Bourail
# 5            None         None                     Kaalualu Beach
# 8            None         None       Prevelly Beach Magaret River
# 9            None         None                        Hakahau Bay
# ...           ...          ...                                ...
# 2804         None         None                      Midnight Lump
# 2807         None         None  The Fountain Pub in Tenbury Wells
# 2808  -46.4213005  168.2195689                        Oreti Beach
# 2809  -31.9283087  133.0110750                             Penong
# 2810         None         None                       Saint Pierre
#
# [818 rows x 16 columns]
# Date                818
# Year                818
# Type                818
# Country             818
# Location            818
# Activity            796
# Name                806
# Sex                 783
# Age                 620
# Injury              814
# Fatal Y/N           813
# Species             552
# CountryCode         818
# latitude            409
# longitude           409
# cleaned_location    818
# dtype: int64

# %%
coord_notfound[["latitude", "longitude"]] = coord_notfound.apply(
    lambda row: get_coordinates(row["cleaned_location"], row["CountryCode"]), axis=1, result_type="expand"
)
# Out:
# [{'place_id': 278535176, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 3776653, 'lat': '26.5356810', 'lon': '-78.6953623', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4934556310655747, 'addresstype': 'city', 'name': 'City of Freeport', 'display_name': 'City of Freeport, The Bahamas', 'boundingbox': ['26.2890000', '26.7231863', '-78.9266868', '-78.3055203']}]
# [{'place_id': 281871453, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 129535681, 'lat': '26.9411913', 'lon': '-80.0724142', 'class': 'leisure', 'type': 'park', 'place_rank': 24, 'importance': 0.08003500190737771, 'addresstype': 'park', 'name': 'Jupiter Beach Park', 'display_name': 'Jupiter Beach Park, Jupiter, Palm Beach County, Florida, United States', 'boundingbox': ['26.9385898', '26.9440290', '-80.0743346', '-80.0700683']}]
# [{'place_id': 198528224, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1324737057, 'lat': '32.6441821', 'lon': '34.9368330', 'class': 'waterway', 'type': 'stream', 'place_rank': 22, 'importance': 0.3645403454506537, 'addresstype': 'stream', 'name': 'נחל מהר"ל', 'display_name': 'נחל מהר"ל, מועצה אזורית חוף הכרמל, נפת חדרה, מחוז חיפה, 3085000, ישראל', 'boundingbox': ['32.6441362', '32.6442280', '34.9366950', '34.9369709']}]
# [{'place_id': 18256731, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 3175109, 'lat': '-38.3456231', 'lon': '141.6042304', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.44979811026237654, 'addresstype': 'town', 'name': 'Portland', 'display_name': 'Portland, Shire of Glenelg, Victoria, 3305, Australia', 'boundingbox': ['-38.4065200', '-38.3205660', '141.5667680', '141.6502140']}]
# [{'place_id': 23683736, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 31296586, 'lat': '-27.0502054', 'lon': '153.1931272', 'class': 'highway', 'type': 'track', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': 'Ocean Beach Access Track', 'display_name': 'Ocean Beach Access Track, Woorim, Greater Brisbane, City of Moreton Bay, Queensland, 4507, Australia', 'boundingbox': ['-27.0576098', '-27.0424329', '153.1890860', '153.1982355']}]
# [{'place_id': 17737307, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 7122442, 'lat': '-32.8967035', 'lon': '134.0971532', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.16004000076295108, 'addresstype': 'city_district', 'name': 'Westall', 'display_name': 'Westall, The District Council of Streaky Bay, South Australia, 5680, Australia', 'boundingbox': ['-32.9288807', '-32.8642870', '134.0595549', '134.1206889']}]
# [{'place_id': 23458090, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 23583826, 'lat': '-26.7929139', 'lon': '153.1390700', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.05338943846799417, 'addresstype': 'road', 'name': 'Gladstone Parade', 'display_name': 'Gladstone Parade, Central Caloundra, Moffat Beach, Sunshine Coast Regional, Queensland, 4551, Australia', 'boundingbox': ['-26.7939040', '-26.7919237', '153.1389116', '153.1392283']}]
# [{'place_id': 276172733, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 3594851, 'lat': '23.6940663', 'lon': '-15.9431274', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4799056519994482, 'addresstype': 'city', 'name': 'Dakhla ⴷⴰⵅⵍⴰ الداخلة', 'display_name': 'Dakhla ⴷⴰⵅⵍⴰ الداخلة, Pachalik de Dakhla باشوية الداخلة, Dakhla-Oued Ed-Dahab ⴷⴰⵅⵍⴰ-ⵡⴰⴷ ⴷⴰⵀⴰⴱ الداخلة-وادي الذهب, Maroc ⵍⵎⵖⵔⵉⴱ المغرب', 'boundingbox': ['23.6271591', '23.8195717', '-16.0069916', '-15.8838879']}]
# [{'place_id': 22787053, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 977998042, 'lat': '-19.9776360', 'lon': '148.2591173', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10671491950865947, 'addresstype': 'beach', 'name': 'Coral Bay', 'display_name': 'Coral Bay, Horseshoe Bay, Coral Sea, Whitsunday Regional, Queensland, Australia', 'boundingbox': ['-19.9778769', '-19.9774061', '148.2589974', '148.2592438']}]
# [{'place_id': 350010975, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 119227, 'lat': '21.5935975', 'lon': '-158.1044697', 'class': 'boundary', 'type': 'census', 'place_rank': 25, 'importance': 0.3886201624950686, 'addresstype': 'locality', 'name': 'Haleiwa', 'display_name': 'Haleiwa, Waialua, Honolulu County, Hawaii, 96712, United States', 'boundingbox': ['21.5755780', '21.6116240', '-158.1224310', '-158.0899060']}]
# [{'place_id': 309891169, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 358074983, 'lat': '39.5649956', 'lon': '-95.0369113', 'class': 'landuse', 'type': 'reservoir', 'place_rank': 30, 'importance': 3.500190737769158e-05, 'addresstype': 'landuse', 'name': 'Dead Mans Hole', 'display_name': 'Dead Mans Hole, Southwest Old Highway Road, Rushville, Buchanan County, Missouri, 64484, United States', 'boundingbox': ['39.5649456', '39.5650456', '-95.0369613', '-95.0368613']}]
# [{'place_id': 329280266, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 399158027, 'lat': '40.7478046', 'lon': '-74.0484829', 'class': 'shop', 'type': 'clothes', 'place_rank': 30, 'importance': 6.566796368348237e-05, 'addresstype': 'shop', 'name': 'Rainbows', 'display_name': 'Rainbows, Central Avenue, The Heights, Jersey City, Hudson County, New Jersey, 07307, United States', 'boundingbox': ['40.7476902', '40.7479190', '-74.0486915', '-74.0482742']}]
# [{'place_id': 19648372, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 5728885, 'lat': '-33.8716908', 'lon': '151.2282875', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.3898810858579735, 'addresstype': 'suburb', 'name': 'Elizabeth Bay', 'display_name': 'Elizabeth Bay, Council of the City of Sydney, New South Wales, 2011, Australia', 'boundingbox': ['-33.8753265', '-33.8680621', '151.2248500', '151.2317647']}]
# [{'place_id': 23319984, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 47288064, 'lat': '-25.1268353', 'lon': '152.5809713', 'class': 'highway', 'type': 'tertiary', 'place_rank': 26, 'importance': 0.05337189822232392, 'addresstype': 'road', 'name': 'Walkers Point Road', 'display_name': 'Walkers Point Road, Woodgate, Woodgate Beach, Bundaberg Region, Queensland, Australia', 'boundingbox': ['-25.1292232', '-25.1231982', '152.5780034', '152.5850158']}]
# [{'place_id': 350043240, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1604572080, 'lat': '21.6028867', 'lon': '-158.1074070', 'class': 'natural', 'type': 'cape', 'place_rank': 22, 'importance': 0.10671317998016325, 'addresstype': 'cape', 'name': 'Puaʻena Point', 'display_name': 'Puaʻena Point, Honolulu County, Hawaii, 96712, United States', 'boundingbox': ['21.6028367', '21.6029367', '-158.1074570', '-158.1073570']}]
# [{'place_id': 300037283, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 150976820, 'lat': '37.5954929', 'lon': '-122.4941424', 'class': 'place', 'type': 'neighbourhood', 'place_rank': 20, 'importance': 0.13338846494239717, 'addresstype': 'neighbourhood', 'name': 'Linda Mar', 'display_name': 'Linda Mar, Pacifica, San Mateo County, California, 94044, United States', 'boundingbox': ['37.5854929', '37.6054929', '-122.5041424', '-122.4841424']}]
# [{'place_id': 218439507, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1504701, 'lat': '15.9166670', 'lon': '120.3333330', 'class': 'boundary', 'type': 'administrative', 'place_rank': 8, 'importance': 0.5565392384324315, 'addresstype': 'state', 'name': 'Pangasinan', 'display_name': 'Pangasinan, Ilocos Region, Philippines', 'boundingbox': ['15.6186428', '16.5788824', '119.6095165', '120.9202823']}]
# [{'place_id': 264018261, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 3892769, 'lat': '41.3540398', 'lon': '-8.7435403', 'class': 'boundary', 'type': 'administrative', 'place_rank': 14, 'importance': 0.5194318010824852, 'addresstype': 'city', 'name': 'Vila do Conde', 'display_name': 'Vila do Conde, Porto, Portugal', 'boundingbox': ['41.2554949', '41.4257091', '-8.7680529', '-8.6106236']}]
# [{'place_id': 333747425, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 93710634, 'lat': '40.6318634', 'lon': '-73.2081428', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.2292915155073439, 'addresstype': 'beach', 'name': 'Lighthouse Beach', 'display_name': 'Lighthouse Beach, Kismet, Town of Islip, Suffolk County, New York, United States', 'boundingbox': ['40.6304072', '40.6330819', '-73.2129403', '-73.2045301']}]
# [{'place_id': 403029082, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 12709038578, 'lat': '37.1521707', 'lon': '-91.3443469', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10671861982146942, 'addresstype': 'beach', 'name': 'Beach 3', 'display_name': 'Beach 3, Shannon County, Missouri, 65466, United States', 'boundingbox': ['37.1521207', '37.1522207', '-91.3443969', '-91.3442969']}]
# [{'place_id': 283332781, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1131832869, 'lat': '25.1435504', 'lon': '-80.9223041', 'class': 'leisure', 'type': 'marina', 'place_rank': 30, 'importance': 3.000152590214416e-05, 'addresstype': 'leisure', 'name': 'Flamingo Marina', 'display_name': 'Flamingo Marina, Flamingo Lodge Highway, Monroe County, Florida, United States', 'boundingbox': ['25.1430428', '25.1440597', '-80.9235742', '-80.9220178']}]
# [{'place_id': 42998443, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 171375109, 'lat': '27.1958012', 'lon': '33.8422382', 'class': 'leisure', 'type': 'beach_resort', 'place_rank': 30, 'importance': 5.735179674978283e-05, 'addresstype': 'leisure', 'name': 'Dream Beach', 'display_name': 'Dream Beach, شارع الشيراتون, القرى السياحية, الفرسان, الغردقة, البحر الأحمر, 54811, مصر', 'boundingbox': ['27.1953875', '27.1962649', '33.8418891', '33.8425772']}]
# [{'place_id': 281530302, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 15436188, 'lat': '29.7585251', 'lon': '-95.2672745', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.05341115358205536, 'addresstype': 'road', 'name': 'Flagship Drive', 'display_name': 'Flagship Drive, Pleasantville, Houston, Harris County, Texas, 77029, United States', 'boundingbox': ['29.7584759', '29.7585788', '-95.2685855', '-95.2659637']}]
# [{'place_id': 425715981, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 303850827, 'lat': '21.5208318', 'lon': '-157.8372577', 'class': 'tourism', 'type': 'attraction', 'place_rank': 30, 'importance': 0.244781979759108, 'addresstype': 'tourism', 'name': 'Kualoa Ranch', 'display_name': 'Kualoa Ranch, 49-560, Kamehameha Highway, Kaneohe, Honolulu County, Hawaii, 96744, United States', 'boundingbox': ['21.5205576', '21.5209855', '-157.8373727', '-157.8371514']}]
# [{'place_id': 335321818, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 816347625, 'lat': '42.2693225', 'lon': '-70.7505398', 'class': 'natural', 'type': 'reef', 'place_rank': 22, 'importance': 0.10671815289539938, 'addresstype': 'reef', 'name': 'Davis Ledge', 'display_name': 'Davis Ledge, Scituate, Plymouth County, Massachusetts, United States', 'boundingbox': ['42.2675599', '42.2712755', '-70.7526827', '-70.7492495']}]
# [{'place_id': 29463589, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1277773965, 'lat': '-33.9349809', 'lon': '22.4291790', 'class': 'highway', 'type': 'cycleway', 'place_rank': 27, 'importance': 0.040054101625085825, 'addresstype': 'road', 'name': 'Supertubes', 'display_name': 'Supertubes, George Ward 22, George Local Municipality, Garden Route District Municipality, Western Cape, 6530, South Africa', 'boundingbox': ['-33.9357496', '-33.9340595', '22.4287086', '22.4293672']}]
# [{'place_id': 24431195, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1811181541, 'lat': '-17.3861923', 'lon': '128.3310959', 'class': 'tourism', 'type': 'camp_site', 'place_rank': 30, 'importance': 4.6479743648386624e-05, 'addresstype': 'tourism', 'name': 'Kurrajong Campground', 'display_name': 'Kurrajong Campground, Kurrajong Campground Trail, Purnululu, Shire of Halls Creek, Western Australia, Australia', 'boundingbox': ['-17.3862423', '-17.3861423', '128.3310459', '128.3311459']}]
# [{'place_id': 282884657, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1216593, 'lat': '26.3586885', 'lon': '-80.0830984', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.5808557148353827, 'addresstype': 'city', 'name': 'Boca Raton', 'display_name': 'Boca Raton, Palm Beach County, Florida, United States', 'boundingbox': ['26.3206768', '26.4246101', '-80.1710745', '-80.0636640']}]
# [{'place_id': 281312672, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 11116434, 'lat': '24.5515624', 'lon': '-81.8113766', 'class': 'highway', 'type': 'service', 'place_rank': 27, 'importance': 0.04004000076295108, 'addresstype': 'road', 'name': 'Outer Mole Road', 'display_name': 'Outer Mole Road, Truman Annex1, Key West, Monroe County, Florida, 33041, United States', 'boundingbox': ['24.5488633', '24.5550677', '-81.8114700', '-81.8092297']}]
# [{'place_id': 278729217, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 119016, 'lat': '30.4213090', 'lon': '-87.2169149', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.5971889862741804, 'addresstype': 'city', 'name': 'Pensacola', 'display_name': 'Pensacola, Escambia County, Florida, United States', 'boundingbox': ['30.3955428', '30.5104858', '-87.2588885', '-87.1497213']}]
# [{'place_id': 24091697, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6063482, 'lat': '-31.1900000', 'lon': '152.9761111', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.33632164909184187, 'addresstype': 'locality', 'name': 'Crescent Head', 'display_name': 'Crescent Head, Kempsey Shire Council, New South Wales, 2440, Australia', 'boundingbox': ['-31.3105318', '-31.1175905', '152.8519636', '153.0053484']}]
# [{'place_id': 301271430, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3760508757, 'lat': '47.5770255', 'lon': '-121.2715212', 'class': 'natural', 'type': 'peak', 'place_rank': 18, 'importance': 0.16000999999999999, 'addresstype': 'peak', 'name': 'Otter Point', 'display_name': 'Otter Point, King County, Washington, United States', 'boundingbox': ['47.5769755', '47.5770755', '-121.2715712', '-121.2714712']}]
# [{'place_id': 306477441, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 17935949, 'lat': '39.7611067', 'lon': '-105.6829980', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.38584692642506985, 'addresstype': 'town', 'name': 'Empire', 'display_name': 'Empire, Clear Creek County, Colorado, 80438, United States', 'boundingbox': ['39.7554030', '39.7653980', '-105.6891040', '-105.6768660']}]
# [{'place_id': 350151953, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 298172593, 'lat': '20.9133131', 'lon': '-156.3923755', 'class': 'leisure', 'type': 'park', 'place_rank': 24, 'importance': 0.08004443656061644, 'addresstype': 'park', 'name': 'Baldwin Beach Park', 'display_name': 'Baldwin Beach Park, Paia, Maui County, Hawaii, United States', 'boundingbox': ['20.9120051', '20.9144320', '-156.3932439', '-156.3896306']}]
# [{'place_id': 333747425, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 93710634, 'lat': '40.6318634', 'lon': '-73.2081428', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.2292915155073439, 'addresstype': 'beach', 'name': 'Lighthouse Beach', 'display_name': 'Lighthouse Beach, Kismet, Town of Islip, Suffolk County, New York, United States', 'boundingbox': ['40.6304072', '40.6330819', '-73.2129403', '-73.2045301']}]
# [{'place_id': 29324786, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 53193358, 'lat': '-31.9841774', 'lon': '115.8248108', 'class': 'leisure', 'type': 'marina', 'place_rank': 30, 'importance': 7.485389486529362e-05, 'addresstype': 'leisure', 'name': 'Royal Perth Yacht Club', 'display_name': 'Royal Perth Yacht Club, Australia II Drive, Crawley, City of Perth, Western Australia, 6009, Australia', 'boundingbox': ['-31.9859779', '-31.9826404', '115.8232035', '115.8264571']}]
# [{'place_id': 282322019, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 11520689, 'lat': '17.9204087', 'lon': '-87.9621768', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.38206711876003785, 'addresstype': 'town', 'name': 'San Pedro Town', 'display_name': 'San Pedro Town, Belize District, Belize', 'boundingbox': ['17.8747223', '17.9742567', '-88.0279340', '-87.9264977']}]
# [{'place_id': 20567634, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 9515322970, 'lat': '-33.9779841', 'lon': '151.2557506', 'class': 'natural', 'type': 'cape', 'place_rank': 22, 'importance': 0.10674912718394748, 'addresstype': 'cape', 'name': 'Buchan Point', 'display_name': 'Buchan Point, New South Wales, 2036, Australia', 'boundingbox': ['-33.9780341', '-33.9779341', '151.2557006', '151.2558006']}]
# [{'place_id': 19224802, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 113754846, 'lat': '-34.1461313', 'lon': '147.1681211', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.13337959487296863, 'addresstype': 'hamlet', 'name': 'Bull Beds', 'display_name': 'Bull Beds, Bland Shire Council, New South Wales, Australia', 'boundingbox': ['-34.1661313', '-34.1261313', '147.1481211', '147.1881211']}]
# [{'place_id': 29471665, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 30832297, 'lat': '-32.0358569', 'lon': '115.7446898', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10674152056153198, 'addresstype': 'beach', 'name': 'Port Beach', 'display_name': 'Port Beach, North Fremantle, City of Fremantle, Western Australia, Australia', 'boundingbox': ['-32.0408465', '-32.0312763', '115.7415603', '115.7463876']}]
# [{'place_id': 323625644, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 158628306, 'lat': '41.0336768', 'lon': '-79.2514282', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.2739939650991996, 'addresstype': 'hamlet', 'name': 'Mayport', 'display_name': 'Mayport, Redbank Township, Clarion County, Pennsylvania, 16230, United States', 'boundingbox': ['41.0136768', '41.0536768', '-79.2714282', '-79.2314282']}]
# [{'place_id': 349647708, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 821472035, 'lat': '55.5481127', 'lon': '-133.2923757', 'class': 'place', 'type': 'islet', 'place_rank': 20, 'importance': 0.1333433333333333, 'addresstype': 'islet', 'name': 'Catalina Island', 'display_name': 'Catalina Island, Unorganized Borough, Alaska, United States', 'boundingbox': ['55.5468026', '55.5494279', '-133.2964232', '-133.2884920']}]
# [{'place_id': 316712531, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 11188029, 'lat': '34.6397339', 'lon': '-77.3418348', 'class': 'military', 'type': 'base', 'place_rank': 30, 'importance': 0.4552125719286163, 'addresstype': 'military', 'name': 'Marine Corps Base Camp Lejeune', 'display_name': 'Marine Corps Base Camp Lejeune, Onslow County, North Carolina, 28542, United States', 'boundingbox': ['34.4982408', '34.7483673', '-77.6072062', '-77.1803647']}]
# [{'place_id': 284218250, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 6459894639, 'lat': '18.2216328', 'lon': '-78.2682267', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.14671166781109327, 'addresstype': 'village', 'name': 'Little Bay', 'display_name': 'Little Bay, Westmoreland, Cornwall County, Jamaica', 'boundingbox': ['18.2016328', '18.2416328', '-78.2882267', '-78.2482267']}]
# [{'place_id': 28729240, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 11689992, 'lat': '-23.1436752', 'lon': '113.7701650', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.31682695039514364, 'addresstype': 'town', 'name': 'Coral Bay', 'display_name': 'Coral Bay, Shire Of Carnarvon, Western Australia, 6701, Australia', 'boundingbox': ['-23.1516121', '-23.1324610', '113.7655750', '113.7796429']}]
# [{'place_id': 349881404, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 368391844, 'lat': '22.0059901', 'lon': '-159.7760574', 'class': 'natural', 'type': 'bay', 'place_rank': 22, 'importance': 0.10670903868162049, 'addresstype': 'bay', 'name': "Waiapua'a Bay", 'display_name': "Waiapua'a Bay, Kauaʻi County, Hawaii, United States", 'boundingbox': ['22.0059401', '22.0060401', '-159.7761074', '-159.7760074']}]
# [{'place_id': 23807394, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 579802343, 'lat': '-27.9812027', 'lon': '153.4282011', 'class': 'building', 'type': 'residential', 'place_rank': 30, 'importance': 6.701228351258133e-05, 'addresstype': 'building', 'name': 'Melaleuca', 'display_name': 'Melaleuca, Pacific Street, Main Beach, Gold Coast City, Queensland, 4217, Australia', 'boundingbox': ['-27.9812705', '-27.9811349', '153.4280391', '153.4283631']}]
# [{'place_id': 279921067, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 369137717, 'lat': '27.6886419', 'lon': '-82.5723193', 'class': 'natural', 'type': 'bay', 'place_rank': 22, 'importance': 0.476846016000311, 'addresstype': 'bay', 'name': 'Tampa Bay', 'display_name': 'Tampa Bay, Hillsborough County, Florida, United States', 'boundingbox': ['27.6885919', '27.6886919', '-82.5723693', '-82.5722693']}]
# [{'place_id': 17883951, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2110130, 'lat': '-35.8182635', 'lon': '137.1566125', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.5020362661484773, 'addresstype': 'island', 'name': 'Kangaroo Island', 'display_name': 'Kangaroo Island, Kangaroo Island Council, South Australia, Australia', 'boundingbox': ['-36.0753153', '-35.5611880', '136.5329419', '138.1349059']}]
# [{'place_id': 41908742, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 271182010, 'lat': '27.7257079', 'lon': '34.2590350', 'class': 'tourism', 'type': 'attraction', 'place_rank': 30, 'importance': 6.053788052181304e-05, 'addresstype': 'tourism', 'name': 'Shark Reef', 'display_name': 'Shark Reef, طريق مدخل راس محمد, جنوب سيناء, مصر', 'boundingbox': ['27.7256579', '27.7257579', '34.2589850', '34.2590850']}]
# [{'place_id': 282362065, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 119070, 'lat': '25.1092910', 'lon': '-80.4240160', 'class': 'boundary', 'type': 'census', 'place_rank': 25, 'importance': 0.4227680920177199, 'addresstype': 'locality', 'name': 'Key Largo', 'display_name': 'Key Largo, Monroe County, Florida, United States', 'boundingbox': ['25.0337640', '25.1848220', '-80.5013400', '-80.3498470']}]
# [{'place_id': 281895507, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 358696407, 'lat': '26.7722910', 'lon': '-82.2662057', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.25725756847226283, 'addresstype': 'island', 'name': 'Gasparilla Island', 'display_name': 'Gasparilla Island, Lee County, Florida, 33921, United States', 'boundingbox': ['26.4522910', '27.0922910', '-82.5862057', '-81.9462057']}]
# [{'place_id': 20197979, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 10593508, 'lat': '-40.7605718', 'lon': '145.2945184', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.3370188667185515, 'addresstype': 'village', 'name': 'Stanley', 'display_name': 'Stanley, Circular Head, Tasmania, 7331, Australia', 'boundingbox': ['-40.8149710', '-40.7123400', '145.2405650', '145.3086700']}]
# [{'place_id': 278765149, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 249729112, 'lat': '24.1836097', 'lon': '-76.4565522', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.1067179880979629, 'addresstype': 'beach', 'name': 'Pig Beach', 'display_name': 'Pig Beach, Exuma, The Bahamas', 'boundingbox': ['24.1827008', '24.1843412', '-76.4568355', '-76.4563346']}]
# [{'place_id': 24221650, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6069946, 'lat': '-28.2566667', 'lon': '153.5761111', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.16004958800640878, 'addresstype': 'town', 'name': 'Kingscliff', 'display_name': 'Kingscliff, Tweed Shire Council, New South Wales, 2487, Australia', 'boundingbox': ['-28.2884646', '-28.2339415', '153.5594628', '153.5859304']}]
# [{'place_id': 274931756, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 168678238, 'lat': '29.1172600', 'lon': '-13.5517947', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10670416800183105, 'addresstype': 'beach', 'name': 'Playa de Famara', 'display_name': 'Playa de Famara, Caleta de Famara, España', 'boundingbox': ['29.1155617', '29.1190168', '-13.5609286', '-13.5472464']}]
# [{'place_id': 18165157, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 36701460, 'lat': '-38.1493248', 'lon': '144.3598241', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.5711610393836019, 'addresstype': 'city', 'name': 'Geelong', 'display_name': 'Geelong, City of Greater Geelong, Victoria, 3220, Australia', 'boundingbox': ['-38.3093248', '-37.9893248', '144.1998241', '144.5198241']}]
# [{'place_id': 24091697, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6063482, 'lat': '-31.1900000', 'lon': '152.9761111', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.33632164909184187, 'addresstype': 'locality', 'name': 'Crescent Head', 'display_name': 'Crescent Head, Kempsey Shire Council, New South Wales, 2440, Australia', 'boundingbox': ['-31.3105318', '-31.1175905', '152.8519636', '153.0053484']}]
# [{'place_id': 29551348, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 979926241, 'lat': '-32.9887705', 'lon': '27.9421981', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.053387283894102355, 'addresstype': 'road', 'name': 'Beach Road', 'display_name': 'Beach Road, Nahoon Mouth, Buffalo City Ward 18, East London, Buffalo City Metropolitan Municipality, Eastern Cape, 5241, South Africa', 'boundingbox': ['-32.9888115', '-32.9884824', '27.9401341', '27.9442382']}]
# [{'place_id': 287753036, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 849908895, 'lat': '16.6913890', 'lon': '-99.6266670', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.13337083466849772, 'addresstype': 'hamlet', 'name': 'Barra Vieja', 'display_name': 'Barra Vieja, San Andrés Playa Encantada (El Podrido), Acapulco de Juárez, Guerrero, 39930, México', 'boundingbox': ['16.6713890', '16.7113890', '-99.6466670', '-99.6066670']}]
# [{'place_id': 23241803, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 11677047, 'lat': '-20.2724940', 'lon': '148.7181466', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.35043161217768787, 'addresstype': 'city_district', 'name': 'Airlie Beach', 'display_name': 'Airlie Beach, Whitsunday Regional, Queensland, 4802, Australia', 'boundingbox': ['-20.2832570', '-20.2614950', '148.7066070', '148.7283090']}]
# [{'place_id': 23683736, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 31296586, 'lat': '-27.0502054', 'lon': '153.1931272', 'class': 'highway', 'type': 'track', 'place_rank': 26, 'importance': 0.053383334859235486, 'addresstype': 'road', 'name': 'Ocean Beach Access Track', 'display_name': 'Ocean Beach Access Track, Woorim, Greater Brisbane, City of Moreton Bay, Queensland, 4507, Australia', 'boundingbox': ['-27.0576098', '-27.0424329', '153.1890860', '153.1982355']}]
# [{'place_id': 306206397, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 11180516, 'lat': '32.4821843', 'lon': '-110.9001941', 'class': 'boundary', 'type': 'census', 'place_rank': 25, 'importance': 0.43033063500823676, 'addresstype': 'census', 'name': 'Catalina', 'display_name': 'Catalina, Pima County, Arizona, United States', 'boundingbox': ['32.4526780', '32.5116990', '-110.9356295', '-110.8617260']}]
# [{'place_id': 350010975, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 119227, 'lat': '21.5935975', 'lon': '-158.1044697', 'class': 'boundary', 'type': 'census', 'place_rank': 25, 'importance': 0.3886201624950686, 'addresstype': 'locality', 'name': 'Haleiwa', 'display_name': 'Haleiwa, Waialua, Honolulu County, Hawaii, 96712, United States', 'boundingbox': ['21.5755780', '21.6116240', '-158.1224310', '-158.0899060']}]
# [{'place_id': 29045478, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 11689636, 'lat': '-31.7282352', 'lon': '115.7199225', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.25725756847226283, 'addresstype': 'suburb', 'name': 'Burns Beach', 'display_name': 'Burns Beach, City of Joondalup, Western Australia, 6028, Australia', 'boundingbox': ['-31.7309440', '-31.7119390', '115.7062780', '115.7353080']}]
# [{'place_id': 348889901, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 904924438, 'lat': '21.4769650', 'lon': '-158.2209082', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.1341073487755671, 'addresstype': 'beach', 'name': 'Mākaha beach', 'display_name': 'Mākaha beach, Makaha, Honolulu County, Hawaii, United States', 'boundingbox': ['21.4754504', '21.4786443', '-158.2234235', '-158.2196030']}]
# [{'place_id': 283666125, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 154335289, 'lat': '25.6968351', 'lon': '-80.1635261', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.49960231682782874, 'addresstype': 'village', 'name': 'Key Biscayne', 'display_name': 'Key Biscayne, Miami-Dade County, Florida, 33149, United States', 'boundingbox': ['25.6768351', '25.7168351', '-80.1835261', '-80.1435261']}]
# [{'place_id': 317074233, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1627220705, 'lat': '35.2252064', 'lon': '-75.5279144', 'class': 'natural', 'type': 'cape', 'place_rank': 22, 'importance': 0.4737172864892395, 'addresstype': 'cape', 'name': 'Cape Hatteras', 'display_name': 'Cape Hatteras, Dare County, North Carolina, 27920, United States', 'boundingbox': ['35.2251564', '35.2252564', '-75.5279644', '-75.5278644']}]
# [{'place_id': 318798492, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 285278271, 'lat': '34.6987266', 'lon': '-76.6923614', 'class': 'leisure', 'type': 'park', 'place_rank': 24, 'importance': 0.35452338605865286, 'addresstype': 'park', 'name': 'Fort Macon State Park', 'display_name': 'Fort Macon State Park, 2303, Atlantic Beach, Carteret County, North Carolina, 28512, United States', 'boundingbox': ['34.6930173', '34.7043810', '-76.7010180', '-76.6744419']}]
# [{'place_id': 312525592, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 126087, 'lat': '38.3769927', 'lon': '-87.9830886', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.44635990349034044, 'addresstype': 'village', 'name': 'Browns', 'display_name': 'Browns, Edwards County, Illinois, United States', 'boundingbox': ['38.3720230', '38.3814890', '-87.9878320', '-87.9768520']}]
# [{'place_id': 282313846, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 154373727, 'lat': '26.7489586', 'lon': '-82.2620390', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.3636287825383402, 'addresstype': 'hamlet', 'name': 'Boca Grande', 'display_name': 'Boca Grande, Lee County, Florida, 33921, United States', 'boundingbox': ['26.7289586', '26.7689586', '-82.2820390', '-82.2420390']}]
# [{'place_id': 30082348, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 25470100, 'lat': '-33.9618598', 'lon': '25.6186731', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.5463483841579168, 'addresstype': 'city', 'name': 'Gqeberha (Port Elizabeth)', 'display_name': 'Gqeberha (Port Elizabeth), Nelson Mandela Bay Metropolitan Municipality, Eastern Cape, 6006, South Africa', 'boundingbox': ['-34.1218598', '-33.8018598', '25.4586731', '25.7786731']}]
# [{'place_id': 297678786, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 154820708, 'lat': '34.4170886', 'lon': '-119.8291338', 'class': 'amenity', 'type': 'restaurant', 'place_rank': 30, 'importance': 2.8699931334355954e-05, 'addresstype': 'amenity', 'name': 'The Ellwood at Goleta Beach', 'display_name': 'The Ellwood at Goleta Beach, 5905, Sandspit Road, Goleta, Santa Barbara County, California, 93117, United States', 'boundingbox': ['34.4169651', '34.4171903', '-119.8293514', '-119.8289942']}]
# [{'place_id': 24402888, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 11716623, 'lat': '-12.1804346', 'lon': '136.7759913', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.37815731550788406, 'addresstype': 'town', 'name': 'Nhulunbuy', 'display_name': 'Nhulunbuy, Northern Territory, 0880, Australia', 'boundingbox': ['-12.2491130', '-12.1586100', '136.6777000', '136.8563150']}]
# [{'place_id': 279807074, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 552428033, 'lat': '28.2422228', 'lon': '-80.6091074', 'class': 'aeroway', 'type': 'aerodrome', 'place_rank': 30, 'importance': 0.4714288939017935, 'addresstype': 'aeroway', 'name': 'Patrick Space Force Base', 'display_name': 'Patrick Space Force Base, Pineda Causeway, South Patrick Shores, Brevard County, Florida, 32925, United States', 'boundingbox': ['28.2125857', '28.2719805', '-80.6189765', '-80.5974545']}]
# [{'place_id': 319973712, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 20644632, 'lat': '36.7960300', 'lon': '-76.0018859', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.0533988868543526, 'addresstype': 'road', 'name': 'Beacons Reach Court', 'display_name': 'Beacons Reach Court, Virginia Beach, Virginia, 23454, United States', 'boundingbox': ['36.7956010', '36.7960300', '-76.0025420', '-76.0014000']}]
# [{'place_id': 349060531, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 900791152, 'lat': '21.6320695', 'lon': '-157.9205814', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10671294499122604, 'addresstype': 'beach', 'name': 'Pounders Beach', 'display_name': 'Pounders Beach, Laie, Honolulu County, Hawaii, United States', 'boundingbox': ['21.6301790', '21.6344262', '-157.9214662', '-157.9185095']}]
# [{'place_id': 276762239, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 205506887, 'lat': '26.5192249', 'lon': '-78.6410012', 'class': 'building', 'type': 'apartments', 'place_rank': 30, 'importance': 5.372472724493809e-05, 'addresstype': 'building', 'name': 'Watergate', 'display_name': 'Watergate, 20, Watergate Road, City of Freeport, The Bahamas', 'boundingbox': ['26.5190034', '26.5193817', '-78.6412312', '-78.6407171']}]
# [{'place_id': 333591072, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 357545558, 'lat': '40.6417443', 'lon': '-73.1728734', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10671852368963147, 'addresstype': 'beach', 'name': 'Atlantique Beach', 'display_name': 'Atlantique Beach, Lonelyville, Fair Harbor, Town of Islip, Suffolk County, New York, 11770, United States', 'boundingbox': ['40.6416943', '40.6417943', '-73.1729234', '-73.1728234']}]
# [{'place_id': 298302367, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 358777463, 'lat': '41.0654020', 'lon': '-124.1503472', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10669136720836192, 'addresstype': 'beach', 'name': 'Trinidad State Beach', 'display_name': 'Trinidad State Beach, Humboldt County, California, 95570, United States', 'boundingbox': ['41.0653520', '41.0654520', '-124.1503972', '-124.1502972']}]
# [{'place_id': 29551348, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 979926241, 'lat': '-32.9887705', 'lon': '27.9421981', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.053387283894102355, 'addresstype': 'road', 'name': 'Beach Road', 'display_name': 'Beach Road, Nahoon Mouth, Buffalo City Ward 18, East London, Buffalo City Metropolitan Municipality, Eastern Cape, 5241, South Africa', 'boundingbox': ['-32.9888115', '-32.9884824', '27.9401341', '27.9442382']}]
# [{'place_id': 18389018, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2705395644, 'lat': '-39.1352781', 'lon': '146.3752603', 'class': 'natural', 'type': 'cape', 'place_rank': 22, 'importance': 0.3119015040685218, 'addresstype': 'locality', 'name': 'South Point', 'display_name': 'South Point, Wilsons Promontory, Shire of South Gippsland, Victoria, 3960, Australia', 'boundingbox': ['-39.1353281', '-39.1352281', '146.3752103', '146.3753103']}]
# [{'place_id': 388463789, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 12330806683, 'lat': '43.8424808', 'lon': '-82.6477279', 'class': 'tourism', 'type': 'information', 'place_rank': 30, 'importance': 4.795986877236618e-05, 'addresstype': 'tourism', 'name': 'Shipwrecks of the Harbor Beach Area', 'display_name': 'Shipwrecks of the Harbor Beach Area, Harbor View Trail, Harbor Beach, Huron County, Michigan, 48441, United States', 'boundingbox': ['43.8424308', '43.8425308', '-82.6477779', '-82.6476779']}]
# [{'place_id': 29222408, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 46905803, 'lat': '-33.8752222', 'lon': '114.9862430', 'class': 'highway', 'type': 'unclassified', 'place_rank': 26, 'importance': 0.05338008926527806, 'addresstype': 'road', 'name': 'Lefthanders Road', 'display_name': 'Lefthanders Road, Gracetown, Shire Of Augusta Margaret River, Western Australia, 6284, Australia', 'boundingbox': ['-33.8777431', '-33.8735059', '114.9836483', '114.9893484']}]
# [{'place_id': 29499836, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 63521353, 'lat': '-32.4122354', 'lon': '115.7488333', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.05338549401083387, 'addresstype': 'road', 'name': 'Cobblestones Circuit', 'display_name': 'Cobblestones Circuit, Secret Harbour, City of Rockingham, Western Australia, 6174, Australia', 'boundingbox': ['-32.4142933', '-32.4120690', '115.7484651', '115.7506595']}]
# [{'place_id': 29209216, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 11689621, 'lat': '-31.8490984', 'lon': '115.7554654', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.26511848687494144, 'addresstype': 'suburb', 'name': 'Watermans Bay', 'display_name': 'Watermans Bay, City of Stirling, Western Australia, 6020, Australia', 'boundingbox': ['-31.8579580', '-31.8457490', '115.7508100', '115.7690290']}]
# [{'place_id': 18389018, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2705395644, 'lat': '-39.1352781', 'lon': '146.3752603', 'class': 'natural', 'type': 'cape', 'place_rank': 22, 'importance': 0.3119015040685218, 'addresstype': 'locality', 'name': 'South Point', 'display_name': 'South Point, Wilsons Promontory, Shire of South Gippsland, Victoria, 3960, Australia', 'boundingbox': ['-39.1353281', '-39.1352281', '146.3752103', '146.3753103']}]
# [{'place_id': 297818136, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 369162259, 'lat': '38.0474258', 'lon': '-122.9422185', 'class': 'natural', 'type': 'bay', 'place_rank': 22, 'importance': 0.2730660066097438, 'addresstype': 'bay', 'name': 'Drakes Estero', 'display_name': 'Drakes Estero, Marin County, California, 94937, United States', 'boundingbox': ['38.0473758', '38.0474758', '-122.9422685', '-122.9421685']}]
# [{'place_id': 322273824, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 11514154, 'lat': '39.0821084', 'lon': '-76.5264046', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.053384224460212064, 'addresstype': 'road', 'name': 'White Plains Court', 'display_name': 'White Plains Court, Arundel Beach, Tebbston, Severna Park, Anne Arundel County, Maryland, 21146, United States', 'boundingbox': ['39.0820490', '39.0835644', '-76.5282516', '-76.5257782']}]
# [{'place_id': 283253818, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 468507921, 'lat': '26.7936633', 'lon': '-80.0332519', 'class': 'leisure', 'type': 'park', 'place_rank': 24, 'importance': 0.08005429541466388, 'addresstype': 'park', 'name': 'Ocean Reef Park', 'display_name': 'Ocean Reef Park, Palm Beach Isles, Riviera Beach, Palm Beach County, Florida, United States', 'boundingbox': ['26.7927485', '26.7947522', '-80.0344301', '-80.0320354']}]
# [{'place_id': 21523565, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 332339615, 'lat': '-35.6083254', 'lon': '174.5244347', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.2792976647232802, 'addresstype': 'village', 'name': 'Tutukaka', 'display_name': 'Tutukaka, Whangārei District, Northland, New Zealand / Aotearoa', 'boundingbox': ['-35.6283254', '-35.5883254', '174.5044347', '174.5444347']}]
# [{'place_id': 299158367, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4773733659, 'lat': '36.5609908', 'lon': '-121.9526760', 'class': 'natural', 'type': 'cape', 'place_rank': 22, 'importance': 0.10671303044174867, 'addresstype': 'cape', 'name': 'Pescadero Point', 'display_name': 'Pescadero Point, Monterey County, California, 93922, United States', 'boundingbox': ['36.5609408', '36.5610408', '-121.9527260', '-121.9526260']}]
# [{'place_id': 48326520, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 38726964, 'lat': '39.3270541', 'lon': '2.9901968', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10672047684443425, 'addresstype': 'beach', 'name': 'Platja Estanys', 'display_name': 'Platja Estanys, Campos, Migjorn, Illes Balears, España', 'boundingbox': ['39.3252684', '39.3285751', '2.9877846', '2.9906586']}]
# [{'place_id': 299441275, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 40500814, 'lat': '37.3919512', 'lon': '-122.4248528', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.2661671604250825, 'addresstype': 'islet', 'name': 'Seal Rock', 'display_name': 'Seal Rock, California, United States', 'boundingbox': ['37.3911317', '37.3926858', '-122.4254790', '-122.4240724']}]
# ...
# [{'place_id': 322503761, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 357797134, 'lat': '35.8340645', 'lon': '-75.5576681', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10667666666666664, 'addresstype': 'beach', 'name': 'Coquina Beach', 'display_name': 'Coquina Beach, Dare County, North Carolina, United States', 'boundingbox': ['35.8340145', '35.8341145', '-75.5577181', '-75.5576181']}]
# [{'place_id': 277243226, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 2114994435, 'lat': '26.6264927', 'lon': '-78.2832236', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.16004585259784845, 'addresstype': 'town', 'name': 'High Rock', 'display_name': 'High Rock, East Grand Bahama, The Bahamas', 'boundingbox': ['26.5864927', '26.6664927', '-78.3232236', '-78.2432236']}]
# [{'place_id': 332079266, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 5706766, 'lat': '40.7017487', 'lon': '-73.8981213', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.05342509269855799, 'addresstype': 'road', 'name': '70th Avenue', 'display_name': '70th Avenue, Ridgewood, Queens, Queens County, New York, 11385, United States', 'boundingbox': ['40.7007160', '40.7027769', '-73.9016930', '-73.8945483']}]
# [{'place_id': 332843547, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 5707686, 'lat': '40.7788791', 'lon': '-73.7923970', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.05342509269855799, 'addresstype': 'road', 'name': '21st Avenue', 'display_name': '21st Avenue, Queens, Queens County, New York, 11357, United States', 'boundingbox': ['40.7786636', '40.7790320', '-73.7937199', '-73.7910570']}]
# [{'place_id': 335545713, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 358273549, 'lat': '42.2917663', 'lon': '-70.8744900', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10671518806744486, 'addresstype': 'beach', 'name': 'Nantasket Beach', 'display_name': 'Nantasket Beach, Waveland, Hull, Plymouth County, Massachusetts, 02045, United States', 'boundingbox': ['42.2917163', '42.2918163', '-70.8745400', '-70.8744400']}]
# [{'place_id': 349865316, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 150919987, 'lat': '21.3156030', 'lon': '-158.0088040', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.3918112304639682, 'addresstype': 'town', 'name': 'Ewa Beach', 'display_name': 'Ewa Beach, Honolulu County, Hawaii, 96706, United States', 'boundingbox': ['21.2756030', '21.3556030', '-158.0488040', '-157.9688040']}]
# [{'place_id': 279279616, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 153955853, 'lat': '28.9491539', 'lon': '-80.8378300', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.3037270327716202, 'addresstype': 'hamlet', 'name': 'Bethune Beach', 'display_name': 'Bethune Beach, Volusia County, Florida, United States', 'boundingbox': ['28.9291539', '28.9691539', '-80.8578300', '-80.8178300']}]
# [{'place_id': 333898849, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 157636573, 'lat': '43.0564452', 'lon': '-78.9597629', 'class': 'place', 'type': 'hamlet', 'place_rank': 20, 'importance': 0.33490418538826533, 'addresstype': 'hamlet', 'name': 'Sandy Beach', 'display_name': 'Sandy Beach, Town of Grand Island, Erie County, New York, 14304, United States', 'boundingbox': ['43.0364452', '43.0764452', '-78.9797629', '-78.9397629']}]
# [{'place_id': 282151091, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 166553886, 'lat': '26.9605829', 'lon': '-80.0781245', 'class': 'leisure', 'type': 'park', 'place_rank': 24, 'importance': 0.08003500190737771, 'addresstype': 'park', 'name': 'Coral Cove Park', 'display_name': 'Coral Cove Park, Tequesta, Palm Beach County, Florida, United States', 'boundingbox': ['26.9562547', '26.9645145', '-80.0803428', '-80.0761553']}]
# [{'place_id': 28862709, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1939438483, 'lat': '-35.0247822', 'lon': '117.8836080', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.526277110314517, 'addresstype': 'city', 'name': 'Albany', 'display_name': 'Albany, City Of Albany, Western Australia, 6330, Australia', 'boundingbox': ['-35.1847822', '-34.8647822', '117.7236080', '118.0436080']}]
# [{'place_id': 284267498, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 128542336, 'lat': '21.1073236', 'lon': '-75.9321518', 'class': 'leisure', 'type': 'resort', 'place_rank': 30, 'importance': 3.975814450289185e-05, 'addresstype': 'leisure', 'name': 'Blau Costa Verde Beach Resort', 'display_name': 'Blau Costa Verde Beach Resort, Rotonda Playa Pesquero, Playa Pesquero, Rafael Freyre, Holguín, Cuba', 'boundingbox': ['21.1043677', '21.1095011', '-75.9342593', '-75.9291720']}]
# [{'place_id': 18010832, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6639619, 'lat': '-34.4971885', 'lon': '137.4873896', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.33561681144948663, 'addresstype': 'town', 'name': 'Port Victoria', 'display_name': 'Port Victoria, Yorke Peninsula Council, South Australia, 5573, Australia', 'boundingbox': ['-34.5594049', '-34.4653316', '137.4735404', '137.5578358']}]
# [{'place_id': 23110338, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 403484071, 'lat': '-23.4349778', 'lon': '152.0335113', 'class': 'natural', 'type': 'reef', 'place_rank': 22, 'importance': 0.10671423743038069, 'addresstype': 'reef', 'name': 'Sykes Reef', 'display_name': 'Sykes Reef, Coral Sea, Gladstone Regional, Queensland, Australia', 'boundingbox': ['-23.4568687', '-23.4107204', '152.0250817', '152.0546075']}]
# [{'place_id': 399151453, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 18678204, 'lat': '-42.4952787', 'lon': '171.2023809', 'class': 'boundary', 'type': 'protected_area', 'place_rank': 25, 'importance': 0.06671841077286945, 'addresstype': 'protected_area', 'name': 'Arorangi Scenic Reserve', 'display_name': 'Arorangi Scenic Reserve, Grey District, West Coast, New Zealand / Aotearoa', 'boundingbox': ['-42.5025466', '-42.4856078', '171.1881560', '171.2148091']}]
# [{'place_id': 28705994, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 29283079, 'lat': '-31.9953965', 'lon': '115.7511955', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.26921459358551875, 'addresstype': 'beach', 'name': 'Cottesloe Beach', 'display_name': 'Cottesloe Beach, Cottesloe, Town of Cottesloe, Western Australia, Australia', 'boundingbox': ['-31.9972457', '-31.9937898', '115.7501280', '115.7514857']}]
# [{'place_id': 28705994, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 29283079, 'lat': '-31.9953965', 'lon': '115.7511955', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.26921459358551875, 'addresstype': 'beach', 'name': 'Cottesloe Beach', 'display_name': 'Cottesloe Beach, Cottesloe, Town of Cottesloe, Western Australia, Australia', 'boundingbox': ['-31.9972457', '-31.9937898', '115.7501280', '115.7514857']}]
# [{'place_id': 17782098, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6639728, 'lat': '-34.6147220', 'lon': '137.8975010', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.2701992234339303, 'addresstype': 'village', 'name': 'Black Point', 'display_name': 'Black Point, Yorke Peninsula Council, South Australia, 5571, Australia', 'boundingbox': ['-34.6276066', '-34.5841825', '137.8613931', '137.9090082']}]
# [{'place_id': 24136944, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6197158, 'lat': '-31.9283087', 'lon': '133.0110750', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.28651547523719245, 'addresstype': 'town', 'name': 'Penong', 'display_name': 'Penong, Pastoral Unincorporated Area, South Australia, 5690, Australia', 'boundingbox': ['-32.2093531', '-31.7523938', '132.7399840', '133.2131490']}]
# [{'place_id': 282036783, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4684079050, 'lat': '27.8557604', 'lon': '-80.4535013', 'class': 'natural', 'type': 'bay', 'place_rank': 22, 'importance': 0.10669266727702752, 'addresstype': 'bay', 'name': 'Sebastian Inlet', 'display_name': 'Sebastian Inlet, Brevard County, Florida, 34958, United States', 'boundingbox': ['27.8557104', '27.8558104', '-80.4535513', '-80.4534513']}]
# [{'place_id': 32263831, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 137119976, 'lat': '-6.7690817', 'lon': '39.2821865', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10673196993972683, 'addresstype': 'beach', 'name': 'Coco Beach', 'display_name': 'Coco Beach, Msasani, Kinondoni Municipal, Dar es-Salaam, Coastal Zone, Tanzania', 'boundingbox': ['-6.7756158', '-6.7621035', '39.2816125', '39.2841750']}]
# [{'place_id': 282055807, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 369134564, 'lat': '27.8058590', 'lon': '-82.7859355', 'class': 'natural', 'type': 'bay', 'place_rank': 22, 'importance': 0.10671681925688561, 'addresstype': 'bay', 'name': 'Boca Ciega Bay', 'display_name': 'Boca Ciega Bay, Pinellas County, Florida, 33708, United States', 'boundingbox': ['27.8058090', '27.8059090', '-82.7859855', '-82.7858855']}]
# [{'place_id': 295145376, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 7902637223, 'lat': '32.6955515', 'lon': '-117.1533390', 'class': 'waterway', 'type': 'dock', 'place_rank': 20, 'importance': 0.13341061341268023, 'addresstype': 'dock', 'name': 'National Oceanic & Atmospheric Administration', 'display_name': 'National Oceanic & Atmospheric Administration, 1839, San Diego, San Diego County, California, 92101, United States', 'boundingbox': ['32.6955015', '32.6956015', '-117.1533890', '-117.1532890']}]
# [{'place_id': 30833597, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 27564996, 'lat': '-29.8618250', 'lon': '31.0099090', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.6488542929100409, 'addresstype': 'city', 'name': 'Durban', 'display_name': 'Durban, eThekwini Metropolitan Municipality, KwaZulu-Natal, 4057, South Africa', 'boundingbox': ['-30.0218250', '-29.7018250', '30.8499090', '31.1699090']}]
# [{'place_id': 279347870, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 358699809, 'lat': '27.4997598', 'lon': '-82.7139886', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10671583047226671, 'addresstype': 'beach', 'name': 'Manatee County Beach', 'display_name': 'Manatee County Beach, Holmes Beach, Manatee County, Florida, 34218, United States', 'boundingbox': ['27.4997098', '27.4998098', '-82.7140386', '-82.7139386']}]
# [{'place_id': 24292573, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 311779, 'lat': '-5.0000000', 'lon': '145.5000000', 'class': 'boundary', 'type': 'administrative', 'place_rank': 8, 'importance': 0.47355053267340924, 'addresstype': 'state', 'name': 'Madang', 'display_name': 'Madang, Momase Region, Papua Niugini', 'boundingbox': ['-6.0000086', '-3.0000000', '143.9736041', '148.2833333']}]
# [{'place_id': 24292573, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 311779, 'lat': '-5.0000000', 'lon': '145.5000000', 'class': 'boundary', 'type': 'administrative', 'place_rank': 8, 'importance': 0.47355053267340924, 'addresstype': 'state', 'name': 'Madang', 'display_name': 'Madang, Momase Region, Papua Niugini', 'boundingbox': ['-6.0000086', '-3.0000000', '143.9736041', '148.2833333']}]
# [{'place_id': 24292573, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 311779, 'lat': '-5.0000000', 'lon': '145.5000000', 'class': 'boundary', 'type': 'administrative', 'place_rank': 8, 'importance': 0.47355053267340924, 'addresstype': 'state', 'name': 'Madang', 'display_name': 'Madang, Momase Region, Papua Niugini', 'boundingbox': ['-6.0000086', '-3.0000000', '143.9736041', '148.2833333']}]
# [{'place_id': 343605462, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 60845461, 'lat': '44.2070652', 'lon': '-88.4147402', 'class': 'leisure', 'type': 'park', 'place_rank': 24, 'importance': 0.08003500190737771, 'addresstype': 'park', 'name': 'Municipal Beach', 'display_name': 'Municipal Beach, Brighton Beach, Menasha, Winnebago County, Wisconsin, United States', 'boundingbox': ['44.2066779', '44.2074702', '-88.4153412', '-88.4142087']}]
# [{'place_id': 19294265, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 7367859845, 'lat': '-33.8457807', 'lon': '151.2397510', 'class': 'highway', 'type': 'bus_stop', 'place_rank': 30, 'importance': 8.246051728079679e-05, 'addresstype': 'highway', 'name': 'Taronga Zoo Wharf, Athol Wharf Rd', 'display_name': 'Taronga Zoo Wharf, Athol Wharf Rd, Athol Wharf Road, Mosman, Lower North Shore, Sydney, Mosman Municipal Council, New South Wales, 2088, Australia', 'boundingbox': ['-33.8458307', '-33.8457307', '151.2397010', '151.2398010']}]
# [{'place_id': 19914148, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 692319403, 'lat': '-46.4213005', 'lon': '168.2195689', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.27844345352870076, 'addresstype': 'beach', 'name': 'Oreti Beach', 'display_name': 'Oreti Beach, Oreti Community, Southland District, Southland, New Zealand / Aotearoa', 'boundingbox': ['-46.5005244', '-46.3392948', '168.0452748', '168.3061337']}]
# [{'place_id': 24136944, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6197158, 'lat': '-31.9283087', 'lon': '133.0110750', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.28651547523719245, 'addresstype': 'town', 'name': 'Penong', 'display_name': 'Penong, Pastoral Unincorporated Area, South Australia, 5690, Australia', 'boundingbox': ['-32.2093531', '-31.7523938', '132.7399840', '133.2131490']}]

# %%
coord_notfound_2 = coord_notfound.loc[coord_notfound["latitude"].isna()].copy()
coord_notfound_2.to_csv("/Users/emilywu/Desktop/DataLiteracy/MiniProjekt/noCoordFound_2.csv")

# %%
display(coord_notfound_2)
# Out:
#                       Date  Year        Type            Country  \
# 1              8th January  2026  Unprovoked  US Virgin Islands
# 2             3rd January   2026  Unprovoked      New Caledonia
# 5             9th December  2025    Provoked                USA
# 8            10th November  2025  Unprovoked          Australia
# 9             9th November  2025  Unprovoked   French Polynesia
# ...                    ...   ...         ...                ...
# 2798           15-Mar-2000  2000  Unprovoked      NEW CALEDONIA
# 2799           14-Mar-2000  2000  Unprovoked          AUSTRALIA
# 2804              Mar-2000  2000  Unprovoked                USA
# 2807           14-Feb-2000  2000    Provoked            ENGLAND
# 2810  Reported 28-Jan-2000  2000  Watercraft            REUNION
#
#                                Location                          Activity  \
# 1                          Dorsch Beach                        Snorkeling
# 2           Between Bourail and Moindou                      Scuba Diving
# 5                      Ka'alu"alu Beach             Freeing trapped shark
# 8          Prevelly Beach Magaret River                     Foil Boarding
# 9                           Hakahau Bay                          Swimming
# ...                                 ...                               ...
# 2798                               Poum                      Spearfishing
# 2799     McMasters Beach, Central Coast                           Surfing
# 2804  Midnight Lump (38 miles offshore)                      Spearfishing
# 2807  The Fountain Pub in Tenbury Wells  Feeding prawns to captive sharks
# 2810                       Saint Pierre     Canoe with 3 men onboard sank
#
#                         Name Sex  Age  \
# 1              Arlene Lillis   F   56
# 2                    Unknown   M    ?
# 5     Josiah Kaimani Ventura   M   24
# 8              Andy McDonald   M   61
# 9       Not stated (Dentist)   M   40
# ...                      ...  ..  ...
# 2798    Gilbert Bui Van Minh   M   35
# 2799              Craig Ruth   M  NaN
# 2804             Kurt Bickel   M   39
# 2807      Paul Smith, a chef   M  NaN
# 2810       Boulabhaï Ishmael   M  NaN
#
#                                                 Injury Fatal Y/N  \
# 1     Left arm torn off in the attack below the elbow          Y
# 2                              Injuries to upper limbs         N
# 5                                 Bite wounds to thigh         N
# 8                                    No Injury to self         N
# 9                                   Deep Gash to bicep         N
# ...                                                ...       ...
# 2798                                             FATAL         Y
# 2799                                         No Injury         N
# 2804              No injury to diver, speargun damaged         N
# 2807                  Fingers bitten PROVOKED INCIDENT         N
# 2810                                             FATAL         Y
#
#                                                Species  CountryCode latitude  \
# 1                                              Unknown           VI     None
# 2                                               Unknown          NC     None
# 5                                  Black Tip Reef Shark          US     None
# 8                                     Great White Shark          AU     None
# 9                                              3m shark          PF     None
# ...                                                 ...         ...      ...
# 2798                                       Tiger shark?          NC     None
# 2799                           Tiger shark, 4 m [13'] ?          AU     None
# 2804    Shortfin mako shark, 3 m to 3.4 m [10' to 11']           US     None
# 2807  Miami, a 60 cm blacktip  shark and two 60 cm b...          GB     None
# 2810                                                NaN          RE     None
#
#      longitude                   cleaned_location
# 1         None                       Dorsch Beach
# 2         None                            Bourail
# 5         None                     Kaalualu Beach
# 8         None       Prevelly Beach Magaret River
# 9         None                        Hakahau Bay
# ...        ...                                ...
# 2798      None                               Poum
# 2799      None                    McMasters Beach
# 2804      None                      Midnight Lump
# 2807      None  The Fountain Pub in Tenbury Wells
# 2810      None                       Saint Pierre
#
# [409 rows x 16 columns]

# %% [markdown]
# 2. Clean up of locations: removing typos, replacing beach with bay, etc

# %%
def strip_accents(s: str) -> str:
    return "".join(c for c in unicodedata.normalize("NFKD", s) if not unicodedata.combining(c))

def generate_queries(loc: str, country_name: str | None = None):
    if not isinstance(loc, str) or not loc.strip():
        return []
    s = loc.strip()

    # Normalisieren
    s = strip_accents(s)
    s = s.replace("-", " ")
    s = s.replace("’", "'").replace("`", "'").replace('"', "")
    s = re.sub(r"\s+", " ", s).strip()

    variants = []

    # 1) Original
    variants.append(s)

    # 2) Apostrophe komplett weg (einfachster “works often”)
    variants.append(s.replace("'", ""))

    # 3) Häufige Tippfehler / Varianten
    variants.append(re.sub(r"\bbaay\b", "bay", s, flags=re.IGNORECASE))  # Crowdy Baay -> Crowdy Bay
    variants.append(re.sub(r"\bbeach\b", "bay", s, flags=re.IGNORECASE)) # beach -> bay
    variants.append(re.sub(r"\bbeach\b", "cove", s, flags=re.IGNORECASE))
    variants.append(re.sub(r"\bbeach\b", "", s, flags=re.IGNORECASE).strip())  # beach einfach entfernen

    # 4) Wenn mehrere Wörter: nur “Kern” nehmen (z.B. "Prevelly Beach Magaret River" -> "Prevelly Beach")
    tokens = s.split()
    if len(tokens) >= 3:
        variants.append(" ".join(tokens[:2]))
        variants.append(" ".join(tokens[:3]))

    # 5) Stop-Wörter abschneiden (sehr pragmatisch)
    for stop in [" river", " island", " atoll", " point", " reef", " jetty", " harbour", " harbor"]:
        if stop in s.lower():
            cut = s.lower().split(stop)[0].strip()
            if cut:
                variants.append(cut)

    # Dedupe + leere raus
    out = []
    seen = set()
    for v in variants:
        v = (v or "").strip(" ,.")
        if len(v) < 2:
            continue
        key = v.lower()
        if key not in seen:
            out.append(v)
            seen.add(key)

    if country_name and isinstance(country_name, str) and country_name.strip():
        out = [f"{q}, {country_name.strip()}" for q in out] + out

    extra = []

    for v in out:
        v2 = remove_directional_phrases(v)
        if v2 != v:
            extra.append(v2)

        extra.append(keep_last_place_chunk(v))
        extra.append(remove_double_letters(v))

        extra.extend(beach_synonym_variants(v))
        extra.append(last_token_only(v))

    # dedupe
    for v in extra:
        v = v.strip(" ,.")
        if len(v) >= 2 and v.lower() not in seen:
            out.append(v)
            seen.add(v.lower())    

    return out

# %%
def get_coordinates_best_effort(cleaned_location):
    headers = {"User-Agent": "shark-attack-map/1.0 (contact: e12217684@student.tuwien.ac.at)"}
    

    for q in generate_queries(cleaned_location):

        params = {
            "q": q,
            "format": "json",
            "limit": 1,
        }
        res = requests.get("https://nominatim.openstreetmap.org/search", headers=headers, params=params)
        if res.status_code == 200:
            data = res.json()
            if data:
                print(data)
                latlon = (float(data[0]["lat"]), float(data[0]["lon"]))
                return latlon
    return (None, None)

# %%
coord_notfound_2[["latitude", "longitude"]] = coord_notfound_2["cleaned_location"].apply(
    get_coordinates_best_effort
).apply(pd.Series)

# %%
display(coord_notfound_2)
coord_notfound_2.count()
# Out:
#                       Date  Year        Type            Country  \
# 1              8th January  2026  Unprovoked  US Virgin Islands
# 2             3rd January   2026  Unprovoked      New Caledonia
# 5             9th December  2025    Provoked                USA
# 8            10th November  2025  Unprovoked          Australia
# 9             9th November  2025  Unprovoked   French Polynesia
# ...                    ...   ...         ...                ...
# 2798           15-Mar-2000  2000  Unprovoked      NEW CALEDONIA
# 2799           14-Mar-2000  2000  Unprovoked          AUSTRALIA
# 2804              Mar-2000  2000  Unprovoked                USA
# 2807           14-Feb-2000  2000    Provoked            ENGLAND
# 2810  Reported 28-Jan-2000  2000  Watercraft            REUNION
#
#                                Location                          Activity  \
# 1                          Dorsch Beach                        Snorkeling
# 2           Between Bourail and Moindou                      Scuba Diving
# 5                      Ka'alu"alu Beach             Freeing trapped shark
# 8          Prevelly Beach Magaret River                     Foil Boarding
# 9                           Hakahau Bay                          Swimming
# ...                                 ...                               ...
# 2798                               Poum                      Spearfishing
# 2799     McMasters Beach, Central Coast                           Surfing
# 2804  Midnight Lump (38 miles offshore)                      Spearfishing
# 2807  The Fountain Pub in Tenbury Wells  Feeding prawns to captive sharks
# 2810                       Saint Pierre     Canoe with 3 men onboard sank
#
#                         Name Sex  Age  \
# 1              Arlene Lillis   F   56
# 2                    Unknown   M    ?
# 5     Josiah Kaimani Ventura   M   24
# 8              Andy McDonald   M   61
# 9       Not stated (Dentist)   M   40
# ...                      ...  ..  ...
# 2798    Gilbert Bui Van Minh   M   35
# 2799              Craig Ruth   M  NaN
# 2804             Kurt Bickel   M   39
# 2807      Paul Smith, a chef   M  NaN
# 2810       Boulabhaï Ishmael   M  NaN
#
#                                                 Injury Fatal Y/N  \
# 1     Left arm torn off in the attack below the elbow          Y
# 2                              Injuries to upper limbs         N
# 5                                 Bite wounds to thigh         N
# 8                                    No Injury to self         N
# 9                                   Deep Gash to bicep         N
# ...                                                ...       ...
# 2798                                             FATAL         Y
# 2799                                         No Injury         N
# 2804              No injury to diver, speargun damaged         N
# 2807                  Fingers bitten PROVOKED INCIDENT         N
# 2810                                             FATAL         Y
#
#                                                Species  CountryCode  \
# 1                                              Unknown           VI
# 2                                               Unknown          NC
# 5                                  Black Tip Reef Shark          US
# 8                                     Great White Shark          AU
# 9                                              3m shark          PF
# ...                                                 ...         ...
# 2798                                       Tiger shark?          NC
# 2799                           Tiger shark, 4 m [13'] ?          AU
# 2804    Shortfin mako shark, 3 m to 3.4 m [10' to 11']           US
# 2807  Miami, a 60 cm blacktip  shark and two 60 cm b...          GB
# 2810                                                NaN          RE
#
#        latitude   longitude                   cleaned_location
# 1    -35.008658  138.529591                       Dorsch Beach
# 2    -21.567724  165.497130                            Bourail
# 5     18.966377 -155.615713                     Kaalualu Beach
# 8    -33.973059  114.987355       Prevelly Beach Magaret River
# 9           NaN         NaN                        Hakahau Bay
# ...         ...         ...                                ...
# 2798 -20.231655  164.029894                               Poum
# 2799  44.353110  -74.215714                    McMasters Beach
# 2804        NaN         NaN                      Midnight Lump
# 2807  50.932605   -0.322037  The Fountain Pub in Tenbury Wells
# 2810  48.383272    7.471873                       Saint Pierre
#
# [409 rows x 16 columns]
# Date                409
# Year                409
# Type                409
# Country             409
# Location            409
# Activity            399
# Name                403
# Sex                 395
# Age                 318
# Injury              406
# Fatal Y/N           404
# Species             282
# CountryCode         409
# latitude            294
# longitude           294
# cleaned_location    409
# dtype: int64

# %%
coord_notfound_3 = coord_notfound_2.loc[coord_notfound_2["latitude"].isna()].copy()
coord_notfound_3.to_csv("/Users/emilywu/Desktop/DataLiteracy/MiniProjekt/noCoordFound_3.csv")
display(coord_notfound_3)
# Out:
#                      Date  Year        Type           Country  \
# 9            9th November  2025  Unprovoked  French Polynesia
# 13           14th October  2025  Unprovoked          Columbia
# 29              20th July  2025  Unprovoked    Canary Islands
# 35               4th July  2025  Unprovoked      South Africa
# 43    2025-05-26 00:00:00  2025  Unprovoked           Vanuatu
# ...                   ...   ...         ...               ...
# 2664          25-Jul-2001  2001  Unprovoked               USA
# 2715          06-Jan-2001  2001  Watercraft       NEW ZEALAND
# 2716          24-Dec-2000  2000  Unprovoked         AUSTRALIA
# 2755          21-Aug-2000  2000  Unprovoked               USA
# 2804             Mar-2000  2000  Unprovoked               USA
#
#                                         Location                    Activity  \
# 9                                    Hakahau Bay                    Swimming
# 13                             Catagena Province        Swimming with sharks
# 29                                  Los Mollinas      Surfing (Hydrofoiling)
# 35                          Mfazazana Hibberdene                     Fishing
# 43                          Espiitu Santo Island                    Swimming
# ...                                          ...                         ...
# 2664                   Taverniier, Monroe County                         NaN
# 2715                         Sandy Bay/Whananaki                    Kayaking
# 2716                                Flinders Cay                Scuba diving
# 2755  Bouges Bank, Emerald Isle, Carteret County  Swimming out to porpoises
# 2804           Midnight Lump (38 miles offshore)                Spearfishing
#
#                       Name Sex  Age  \
# 9     Not stated (Dentist)   M   40
# 13              Male child   M   14
# 29                 Unknown   M    ?
# 35            Unknown male   M   37
# 43                   Tumas   M   14
# ...                    ...  ..  ...
# 2664                  male   M  NaN
# 2715    Dr. Michael Hogan    M  NaN
# 2716                  male   M   23
# 2755                  male   M  NaN
# 2804           Kurt Bickel   M   39
#
#                                                  Injury Fatal Y/N  \
# 9                                    Deep Gash to bicep         N
# 13                                   Severe hand injury         N
# 29               Lacerations to left leg above the knee         N
# 35                             Mltiple injuries to body         Y
# 43    Multiple injuries to body one hand and leg bit...         Y
# ...                                                 ...       ...
# 2664                                       Minor injury         N
# 2715                            No injury, kayak bitten         N
# 2716                                        Hand bitten         N
# 2755  Severe gash to left hand above wrist, almost s...         N
# 2804               No injury to diver, speargun damaged         N
#
#                                              Species  CountryCode  latitude  \
# 9                                            3m shark          PF       NaN
# 13                                       Nurse shark           CA       NaN
# 29                                       Undetermined          ES       NaN
# 35                                      Undetermined           ZA       NaN
# 43                                         Not stated          VU       NaN
# ...                                               ...         ...       ...
# 2664                                              NaN          US       NaN
# 2715                                      White shark          NZ       NaN
# 2716                                              NaN          AU       NaN
# 2755                                              NaN          US       NaN
# 2804  Shortfin mako shark, 3 m to 3.4 m [10' to 11']           US       NaN
#
#       longitude      cleaned_location
# 9           NaN           Hakahau Bay
# 13          NaN     Catagena Province
# 29          NaN          Los Mollinas
# 35          NaN  Mfazazana Hibberdene
# 43          NaN  Espiitu Santo Island
# ...         ...                   ...
# 2664        NaN            Taverniier
# 2715        NaN    Sandy BayWhananaki
# 2716        NaN          Flinders Cay
# 2755        NaN           Bouges Bank
# 2804        NaN         Midnight Lump
#
# [115 rows x 16 columns]

# %% [markdown]
# 3. Cleanup of locations: further cleanup

# %%
def remove_directional_phrases(s: str) -> str:
    patterns = [
        r"\bnorth of\b", r"\bsouth of\b", r"\beast of\b", r"\bwest of\b",
        r"\bnear\b", r"\boff\b", r"\boff the coast of\b",
        r"\bat the mouth of\b", r"\bin the vicinity of\b",
        r"\bin the area of\b", r"\bin front of\b"
    ]
    out = s
    for p in patterns:
        out = re.sub(p, "", out, flags=re.IGNORECASE)
    return re.sub(r"\s+", " ", out).strip()

# %%
def keep_last_place_chunk(s: str) -> str:
    # trennt bei typischen Präpositionen und nimmt das letzte Segment
    for sep in [" near ", " off ", " at ", " in ", " on "]:
        if sep in s.lower():
            return s.lower().split(sep)[-1].strip()
    return s

# %%
def beach_synonym_variants(s: str) -> list[str]:
    variants = []
    if re.search(r"\bbeach\b", s, flags=re.IGNORECASE):
        variants.extend([
            re.sub(r"\bbeach\b", "bay", s, flags=re.IGNORECASE),
            re.sub(r"\bbeach\b", "cove", s, flags=re.IGNORECASE),
            re.sub(r"\bbeach\b", "point", s, flags=re.IGNORECASE),
            re.sub(r"\bbeach\b", "", s, flags=re.IGNORECASE).strip(),
        ])
    return variants

# %%
def last_token_only(s: str) -> str:
    toks = s.split()
    if len(toks) >= 2:
        return toks[-1]
    return s

# %%
def remove_double_letters(s: str) -> str:
    # z.B. baay -> bay, coove -> cove
    return re.sub(r"(.)\1+", r"\1", s)

# %%
coord_notfound_3[["latitude", "longitude"]] = coord_notfound_3["cleaned_location"].apply(
    get_coordinates_best_effort
).apply(pd.Series)
# Out:
# [{'place_id': 279995906, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1210718, 'lat': '30.2481693', 'lon': '-85.6593633', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.5567836372157328, 'addresstype': 'county', 'name': 'Bay County', 'display_name': 'Bay County, Florida, United States', 'boundingbox': ['29.9010330', '30.5674239', '-85.9998930', '-85.3841500']}]
# [{'place_id': 66634626, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 45756, 'lat': '46.1029536', 'lon': '11.1297425', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.7293133565197413, 'addresstype': 'county', 'name': 'Provincia di Trento', 'display_name': 'Provincia di Trento, Trentino-Alto Adige/Südtirol, Italia', 'boundingbox': ['45.6728669', '46.5330375', '10.4522048', '11.9628023']}]
# [{'place_id': 273732410, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4384079816, 'lat': '37.4931771', 'lon': '-2.1506704', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.14672410391393906, 'addresstype': 'village', 'name': 'Los Molinas', 'display_name': 'Los Molinas, Albox, Valle del Almanzora, Almería, Andalucía, España', 'boundingbox': ['37.4731771', '37.5131771', '-2.1706704', '-2.1306704']}]
# [{'place_id': 30880476, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 262706991, 'lat': '-30.5719444', 'lon': '30.5736111', 'class': 'place', 'type': 'suburb', 'place_rank': 19, 'importance': 0.27490876061231784, 'addresstype': 'suburb', 'name': 'Hibberdene', 'display_name': 'Hibberdene, Hibiscus Coast Ward 13, Hibiscus Coast Local Municipality, Ugu District Municipality, KwaZulu-Natal, South Africa', 'boundingbox': ['-30.5919444', '-30.5519444', '30.5536111', '30.5936111']}]
# [{'place_id': 253596373, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 299133, 'lat': '64.9841821', 'lon': '-18.1059013', 'class': 'boundary', 'type': 'administrative', 'place_rank': 4, 'importance': 0.7851887881317666, 'addresstype': 'country', 'name': 'Ísland', 'display_name': 'Ísland', 'boundingbox': ['63.0859177', '67.3530000', '-25.0135069', '-12.8046162']}]
# [{'place_id': 28688133, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 29277817, 'lat': '-31.9558967', 'lon': '115.8605784', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.6799899746255575, 'addresstype': 'city', 'name': 'Perth', 'display_name': 'Perth, City of Perth, Western Australia, 6000, Australia', 'boundingbox': ['-32.1158967', '-31.7958967', '115.7005784', '116.0205784']}]
# [{'place_id': 28688133, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 29277817, 'lat': '-31.9558967', 'lon': '115.8605784', 'class': 'place', 'type': 'city', 'place_rank': 16, 'importance': 0.6799899746255575, 'addresstype': 'city', 'name': 'Perth', 'display_name': 'Perth, City of Perth, Western Australia, 6000, Australia', 'boundingbox': ['-32.1158967', '-31.7958967', '115.7005784', '116.0205784']}]
# [{'place_id': 316315318, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 19530623, 'lat': '35.9931035', 'lon': '-83.8606180', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.053400911726558295, 'addresstype': 'road', 'name': 'Exemouth Road', 'display_name': 'Exemouth Road, Holston Hills, Knoxville, Knox County, East Tennessee, Tennessee, 37914, United States', 'boundingbox': ['35.9911858', '35.9943872', '-83.8612149', '-83.8593380']}]
# [{'place_id': 253596373, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 299133, 'lat': '64.9841821', 'lon': '-18.1059013', 'class': 'boundary', 'type': 'administrative', 'place_rank': 4, 'importance': 0.7851887881317666, 'addresstype': 'country', 'name': 'Ísland', 'display_name': 'Ísland', 'boundingbox': ['63.0859177', '67.3530000', '-25.0135069', '-12.8046162']}]
# [{'place_id': 254146994, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 12631467, 'lat': '54.5634073', 'lon': '-1.1985613', 'class': 'landuse', 'type': 'residential', 'place_rank': 22, 'importance': 0.10673156404974439, 'addresstype': 'residential', 'name': 'Pallister', 'display_name': 'Pallister, Berwick Hills, Middlesbrough, Tees Valley, England, United Kingdom', 'boundingbox': ['54.5581773', '54.5686066', '-1.2056649', '-1.1952001']}]
# [{'place_id': 288864523, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 115263, 'lat': '30.4893555', 'lon': '-99.7720109', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.5121384649642472, 'addresstype': 'town', 'name': 'Junction', 'display_name': 'Junction, Kimble County, Texas, 76849, United States', 'boundingbox': ['30.4780110', '30.5108210', '-99.7897010', '-99.7462210']}]
# [{'place_id': 304241235, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 181448, 'lat': '46.9180689', 'lon': '-104.0043728', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4540735774087027, 'addresstype': 'town', 'name': 'Beach', 'display_name': 'Beach, Golden Valley County, North Dakota, 58621, United States', 'boundingbox': ['46.9048200', '46.9271630', '-104.0288210', '-103.9865500']}]
# [{'place_id': 279995906, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1210718, 'lat': '30.2481693', 'lon': '-85.6593633', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.5567836372157328, 'addresstype': 'county', 'name': 'Bay County', 'display_name': 'Bay County, Florida, United States', 'boundingbox': ['29.9010330', '30.5674239', '-85.9998930', '-85.3841500']}]
# [{'place_id': 279995906, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1210718, 'lat': '30.2481693', 'lon': '-85.6593633', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.5567836372157328, 'addresstype': 'county', 'name': 'Bay County', 'display_name': 'Bay County, Florida, United States', 'boundingbox': ['29.9010330', '30.5674239', '-85.9998930', '-85.3841500']}]
# [{'place_id': 304241235, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 181448, 'lat': '46.9180689', 'lon': '-104.0043728', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4540735774087027, 'addresstype': 'town', 'name': 'Beach', 'display_name': 'Beach, Golden Valley County, North Dakota, 58621, United States', 'boundingbox': ['46.9048200', '46.9271630', '-104.0288210', '-103.9865500']}]
# [{'place_id': 130229643, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 78662, 'lat': '52.3855297', 'lon': '9.7729005', 'class': 'boundary', 'type': 'administrative', 'place_rank': 20, 'importance': 0.32771111640952466, 'addresstype': 'suburb', 'name': 'Zoo', 'display_name': 'Zoo, Mitte, Hannover, Region Hannover, Niedersachsen, 30175, Deutschland', 'boundingbox': ['52.3724921', '52.3983249', '9.7514942', '9.7916261']}]
# [{'place_id': 280559088, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6603572, 'lat': '31.7952814', 'lon': '-94.1803576', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.5125579413968848, 'addresstype': 'town', 'name': 'Center', 'display_name': 'Center, Shelby County, Texas, 75935, United States', 'boundingbox': ['31.7664489', '31.8189489', '-94.2100955', '-94.1495455']}]
# [{'place_id': 304241235, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 181448, 'lat': '46.9180689', 'lon': '-104.0043728', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4540735774087027, 'addresstype': 'town', 'name': 'Beach', 'display_name': 'Beach, Golden Valley County, North Dakota, 58621, United States', 'boundingbox': ['46.9048200', '46.9271630', '-104.0288210', '-103.9865500']}]
# [{'place_id': 304241235, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 181448, 'lat': '46.9180689', 'lon': '-104.0043728', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4540735774087027, 'addresstype': 'town', 'name': 'Beach', 'display_name': 'Beach, Golden Valley County, North Dakota, 58621, United States', 'boundingbox': ['46.9048200', '46.9271630', '-104.0288210', '-103.9865500']}]
# [{'place_id': 266895158, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 501400082, 'lat': '44.8909604', 'lon': '-0.1436923', 'class': 'landuse', 'type': 'vineyard', 'place_rank': 24, 'importance': 0.08006493553063246, 'addresstype': 'vineyard', 'name': 'Maitre', 'display_name': 'Maitre, Lasserre, Saint-Émilion, Libourne, Gironde, Nouvelle-Aquitaine, France métropolitaine, 33330, France', 'boundingbox': ['44.8905766', '44.8914697', '-0.1446575', '-0.1430106']}]
# [{'place_id': 330700839, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5285594971, 'lat': '40.7477112', 'lon': '-73.9563172', 'class': 'shop', 'type': 'clothes', 'place_rank': 30, 'importance': 9.175936522464359e-05, 'addresstype': 'shop', 'name': 'Fado', 'display_name': 'Fado, 4545, Center Boulevard, Long Island City, Queens, Queens County, New York, 11109, United States', 'boundingbox': ['40.7476612', '40.7477612', '-73.9563672', '-73.9562672']}]
# [{'place_id': 304241235, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 181448, 'lat': '46.9180689', 'lon': '-104.0043728', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4540735774087027, 'addresstype': 'town', 'name': 'Beach', 'display_name': 'Beach, Golden Valley County, North Dakota, 58621, United States', 'boundingbox': ['46.9048200', '46.9271630', '-104.0288210', '-103.9865500']}]
# [{'place_id': 17702209, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 9108117, 'lat': '-34.4100885', 'lon': '138.8321181', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.35960412261764174, 'addresstype': 'municipality', 'name': 'Light Regional Council', 'display_name': 'Light Regional Council, South Australia, Australia', 'boundingbox': ['-34.6320564', '-34.1875626', '138.5598752', '139.1273893']}]
# [{'place_id': 304241235, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 181448, 'lat': '46.9180689', 'lon': '-104.0043728', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4540735774087027, 'addresstype': 'town', 'name': 'Beach', 'display_name': 'Beach, Golden Valley County, North Dakota, 58621, United States', 'boundingbox': ['46.9048200', '46.9271630', '-104.0288210', '-103.9865500']}]
# [{'place_id': 277612731, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 264304755, 'lat': '4.8206800', 'lon': '-52.3630528', 'class': 'aeroway', 'type': 'aerodrome', 'place_rank': 30, 'importance': 0.45039779319602985, 'addresstype': 'aeroway', 'name': 'Aéroport de Cayenne - Félix Éboué', 'display_name': 'Aéroport de Cayenne - Félix Éboué, Route de Rochambeau, Concorde, Matoury, Cayenne, Guyane, 97351, France', 'boundingbox': ['4.8107614', '4.8304581', '-52.3818147', '-52.3418847']}]
# [{'place_id': 106795369, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 287228194, 'lat': '50.8080835', 'lon': '6.3788680', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.24404996673231694, 'addresstype': 'village', 'name': 'Pier', 'display_name': 'Pier, Jüngersdorf, Langerwehe, Kreis Düren, Nordrhein-Westfalen, 52379, Deutschland', 'boundingbox': ['50.7880835', '50.8280835', '6.3588680', '6.3988680']}]
# [{'place_id': 350031766, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 12814094, 'lat': '6.4295092', 'lon': '-162.4073100', 'class': 'boundary', 'type': 'protected_area', 'place_rank': 25, 'importance': 0.6840175561954019, 'addresstype': 'protected_area', 'name': 'Kingman Reef National Wildlife Refuge', 'display_name': 'Kingman Reef National Wildlife Refuge, United States', 'boundingbox': ['6.1779744', '6.6514388', '-162.6816297', '-162.1339885']}]
# [{'place_id': 158538, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1185059209, 'lat': '-16.4860096', 'lon': '-151.6949763', 'class': 'natural', 'type': 'water', 'place_rank': 22, 'importance': 0.1067007774471656, 'addresstype': 'water', 'name': 'Lagoonarium', 'display_name': 'Lagoonarium, Faanui, Bora-Bora, Îles Sous-le-Vent, Polynésie Française, 98730, France', 'boundingbox': ['-16.4867131', '-16.4852904', '-151.6959920', '-151.6938752']}]
# [{'place_id': 263523230, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1180740942, 'lat': '49.9892202', 'lon': '-2.2384698', 'class': 'natural', 'type': 'strait', 'place_rank': 22, 'importance': 0.6812807159773241, 'addresstype': 'strait', 'name': 'English Channel / La Manche', 'display_name': 'English Channel / La Manche', 'boundingbox': ['49.4859736', '50.4924668', '-5.5316217', '1.0546820']}]
# [{'place_id': 334700989, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 8164731, 'lat': '47.1037283', 'lon': '-70.0550253', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.4406614819345932, 'addresstype': 'county', 'name': "L'Islet (MRC)", 'display_name': "L'Islet (MRC), Chaudière-Appalaches, Québec, Canada", 'boundingbox': ['46.7322018', '47.4109862', '-70.4791874', '-69.6252841']}]
# [{'place_id': 334689844, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 365922994, 'lat': '42.3595655', 'lon': '-71.0519869', 'class': 'railway', 'type': 'station', 'place_rank': 30, 'importance': 0.370994928094282, 'addresstype': 'railway', 'name': 'Aquarium', 'display_name': 'Aquarium, State Street, Waterfront, North End, Boston, Suffolk County, Massachusetts, 02109, United States', 'boundingbox': ['42.3545655', '42.3645655', '-71.0569869', '-71.0469869']}]
# [{'place_id': 341574837, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 182450369, 'lat': '43.4717485', 'lon': '-80.5432932', 'class': 'natural', 'type': 'water', 'place_rank': 22, 'importance': 0.10672489433127334, 'addresstype': 'water', 'name': 'Break', 'display_name': 'Break, Waterloo, Region of Waterloo, Ontario, Canada', 'boundingbox': ['43.4717294', '43.4717676', '-80.5433209', '-80.5432656']}]
# [{'place_id': 23086007, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 4097004, 'lat': '-17.7933831', 'lon': '177.9782252', 'class': 'place', 'type': 'island', 'place_rank': 17, 'importance': 0.4943797882789724, 'addresstype': 'island', 'name': 'Viti Levu', 'display_name': 'Viti Levu, Western, Viti', 'boundingbox': ['-18.2756979', '-17.3110359', '177.2430451', '178.6957941']}]
# [{'place_id': 48555537, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 4364573392, 'lat': '32.7920513', 'lon': '13.7375842', 'class': 'natural', 'type': 'beach', 'place_rank': 22, 'importance': 0.10669999008163575, 'addresstype': 'beach', 'name': 'مصيف القربولي', 'display_name': 'مصيف القربولي, محافظة المرقب, ليبيا', 'boundingbox': ['32.7920013', '32.7921013', '13.7375342', '13.7376342']}]
# [{'place_id': 306422946, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 439376, 'lat': '39.1089299', 'lon': '-105.7561639', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.5385054639420128, 'addresstype': 'county', 'name': 'Park County', 'display_name': 'Park County, Colorado, United States', 'boundingbox': ['38.6910970', '39.5681797', '-106.2102060', '-105.3288612']}]
# [{'place_id': 253596373, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 299133, 'lat': '64.9841821', 'lon': '-18.1059013', 'class': 'boundary', 'type': 'administrative', 'place_rank': 4, 'importance': 0.7851887881317666, 'addresstype': 'country', 'name': 'Ísland', 'display_name': 'Ísland', 'boundingbox': ['63.0859177', '67.3530000', '-25.0135069', '-12.8046162']}]
# [{'place_id': 279995906, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1210718, 'lat': '30.2481693', 'lon': '-85.6593633', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.5567836372157328, 'addresstype': 'county', 'name': 'Bay County', 'display_name': 'Bay County, Florida, United States', 'boundingbox': ['29.9010330', '30.5674239', '-85.9998930', '-85.3841500']}]
# [{'place_id': 410976553, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 5638803, 'lat': '33.3061701', 'lon': '44.3872213', 'class': 'boundary', 'type': 'administrative', 'place_rank': 10, 'importance': 0.7086872179941637, 'addresstype': 'city', 'name': 'بغداد', 'display_name': 'بغداد, بلدية المنطقة الخضراء, محافظة بغداد, العراق', 'boundingbox': ['33.1797569', '33.4868251', '44.1846152', '44.5699963']}]
# [{'place_id': 67712656, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 45995, 'lat': '45.7634448', 'lon': '10.1158821', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.5474725728629671, 'addresstype': 'village', 'name': 'Zone', 'display_name': 'Zone, Comunità montana del Sebino bresciano, Brescia, Lombardia, 25050, Italia', 'boundingbox': ['45.7389172', '45.7857875', '10.0911297', '10.1760994']}]
# [{'place_id': 303746840, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 471830051, 'lat': '40.9859653', 'lon': '-111.8927528', 'class': 'tourism', 'type': 'theme_park', 'place_rank': 30, 'importance': 0.37735982282950553, 'addresstype': 'tourism', 'name': 'Lagoon', 'display_name': 'Lagoon, 375, Old Lagoon Race Track, Bayview Heights, Farmington, Davis County, Utah, 84025, United States', 'boundingbox': ['40.9828595', '40.9890518', '-111.8966214', '-111.8885521']}]
# [{'place_id': 18778399, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 2383266, 'lat': '-37.8141705', 'lon': '144.9655616', 'class': 'boundary', 'type': 'administrative', 'place_rank': 18, 'importance': 0.4427950632796455, 'addresstype': 'suburb', 'name': 'Melbourne', 'display_name': 'Melbourne, City of Melbourne, Victoria, Australia', 'boundingbox': ['-37.8555270', '-37.7994460', '144.9514311', '144.9890970']}]
# [{'place_id': 306422946, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 439376, 'lat': '39.1089299', 'lon': '-105.7561639', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.5385054639420128, 'addresstype': 'county', 'name': 'Park County', 'display_name': 'Park County, Colorado, United States', 'boundingbox': ['38.6910970', '39.5681797', '-106.2102060', '-105.3288612']}]
# [{'place_id': 6937961, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 296661, 'lat': '-27.0273601', 'lon': '-48.6535657', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4842567197923163, 'addresstype': 'municipality', 'name': 'Camboriú', 'display_name': 'Camboriú, Região Geográfica Imediata de Itajaí, Região Geográfica Intermediária de Blumenau, Santa Catarina, Região Sul, Brasil', 'boundingbox': ['-27.1550000', '-26.9710000', '-48.8120000', '-48.6105708']}]
# [{'place_id': 8525243, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 314992, 'lat': '-22.0677780', 'lon': '-45.2638890', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.5450391338183554, 'addresstype': 'municipality', 'name': 'Olímpio Noronha', 'display_name': 'Olímpio Noronha, Região Geográfica Imediata de São Lourenço, Região Geográfica Intermediária de Pouso Alegre, Minas Gerais, Região Sudeste, Brasil', 'boundingbox': ['-22.1320793', '-22.0375542', '-45.3394175', '-45.2352620']}]
# [{'place_id': 328741233, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 9184317853, 'lat': '40.1428090', 'lon': '-74.0422302', 'class': 'amenity', 'type': 'restaurant', 'place_rank': 30, 'importance': 4.996643015178176e-05, 'addresstype': 'amenity', 'name': 'Capsized Cafe', 'display_name': 'Capsized Cafe, Central Avenue, Villa Park, Spring Lake Heights, Monmouth County, New Jersey, 07762, United States', 'boundingbox': ['40.1427590', '40.1428590', '-74.0422802', '-74.0421802']}]
# [{'place_id': 279995906, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1210718, 'lat': '30.2481693', 'lon': '-85.6593633', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.5567836372157328, 'addresstype': 'county', 'name': 'Bay County', 'display_name': 'Bay County, Florida, United States', 'boundingbox': ['29.9010330', '30.5674239', '-85.9998930', '-85.3841500']}]
# [{'place_id': 281969655, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6586771, 'lat': '29.8041880', 'lon': '-94.8394057', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4596974871743698, 'addresstype': 'village', 'name': 'Cove', 'display_name': 'Cove, Chambers County, Texas, United States', 'boundingbox': ['29.7680510', '29.8300627', '-94.8461338', '-94.7993833']}]
# [{'place_id': 427020227, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 345274, 'lat': '38.0418669', 'lon': '-1.4906872', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.45670105723186827, 'addresstype': 'town', 'name': 'Mula', 'display_name': 'Mula, Río Mula, Región de Murcia, España', 'boundingbox': ['37.8602240', '38.1899632', '-1.7335724', '-1.3576010']}]
# [{'place_id': 304059034, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 181448, 'lat': '46.9180689', 'lon': '-104.0043728', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4540735774087027, 'addresstype': 'town', 'name': 'Beach', 'display_name': 'Beach, Golden Valley County, North Dakota, 58621, United States', 'boundingbox': ['46.9048200', '46.9271630', '-104.0288210', '-103.9865500']}]
# [{'place_id': 163881, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 10421324, 'lat': '-17.4934609', 'lon': '-149.8947240', 'class': 'building', 'type': 'apartments', 'place_rank': 30, 'importance': 4.5008773937545094e-05, 'addresstype': 'building', 'name': 'Résidence Bleu Lagon', 'display_name': 'Résidence Bleu Lagon, Route de ceinture, Hauru, Haapiti, Moorea-Maiao, Îles du Vent, Polynésie Française, 98729, France', 'boundingbox': ['-17.4938075', '-17.4933804', '-149.8949580', '-149.8943664']}]
# [{'place_id': 57124529, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 11349256, 'lat': '45.9397245', 'lon': '23.6671934', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.45377530513592423, 'addresstype': 'municipality', 'name': 'Cut', 'display_name': 'Cut, Alba, 517206, România', 'boundingbox': ['45.9232677', '45.9798720', '23.6232969', '23.7101680']}]
# [{'place_id': 304059034, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 181448, 'lat': '46.9180689', 'lon': '-104.0043728', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4540735774087027, 'addresstype': 'town', 'name': 'Beach', 'display_name': 'Beach, Golden Valley County, North Dakota, 58621, United States', 'boundingbox': ['46.9048200', '46.9271630', '-104.0288210', '-103.9865500']}]
# [{'place_id': 304059034, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 181448, 'lat': '46.9180689', 'lon': '-104.0043728', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4540735774087027, 'addresstype': 'town', 'name': 'Beach', 'display_name': 'Beach, Golden Valley County, North Dakota, 58621, United States', 'boundingbox': ['46.9048200', '46.9271630', '-104.0288210', '-103.9865500']}]
# [{'place_id': 427020227, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 345274, 'lat': '38.0418669', 'lon': '-1.4906872', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.45670105723186827, 'addresstype': 'town', 'name': 'Mula', 'display_name': 'Mula, Río Mula, Región de Murcia, España', 'boundingbox': ['37.8602240', '38.1899632', '-1.7335724', '-1.3576010']}]
# [{'place_id': 152806, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 3221565093, 'lat': '-17.8419303', 'lon': '-149.2583685', 'class': 'natural', 'type': 'peak', 'place_rank': 18, 'importance': 0.16004539635309376, 'addresstype': 'peak', 'name': 'Area', 'display_name': 'Area, Taiarapu-Ouest, Îles du Vent, Polynésie Française, 98725, France', 'boundingbox': ['-17.8419803', '-17.8418803', '-149.2584185', '-149.2583185']}]
# [{'place_id': 126923683, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 5342978921, 'lat': '50.1824507', 'lon': '8.5979540', 'class': 'shop', 'type': 'hairdresser', 'place_rank': 30, 'importance': 5.440680552372042e-05, 'addresstype': 'shop', 'name': 'Cays', 'display_name': 'Cays, 19, Friedrich-Ludwig-Jahn-Straße, Weißkirchen, Oberursel (Taunus), Hochtaunuskreis, Hessen, 61440, Deutschland', 'boundingbox': ['50.1824007', '50.1825007', '8.5979040', '8.5980040']}]
# [{'place_id': 339674846, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 182450369, 'lat': '43.4717485', 'lon': '-80.5432932', 'class': 'natural', 'type': 'water', 'place_rank': 22, 'importance': 0.10672489433127334, 'addresstype': 'water', 'name': 'Break', 'display_name': 'Break, Waterloo, Region of Waterloo, Ontario, Canada', 'boundingbox': ['43.4717294', '43.4717676', '-80.5433209', '-80.5432656']}]
# [{'place_id': 253661899, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 299133, 'lat': '64.9841821', 'lon': '-18.1059013', 'class': 'boundary', 'type': 'administrative', 'place_rank': 4, 'importance': 0.7851887881317666, 'addresstype': 'country', 'name': 'Ísland', 'display_name': 'Ísland', 'boundingbox': ['63.0859177', '67.3530000', '-25.0135069', '-12.8046162']}]
# [{'place_id': 304059034, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 181448, 'lat': '46.9180689', 'lon': '-104.0043728', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4540735774087027, 'addresstype': 'town', 'name': 'Beach', 'display_name': 'Beach, Golden Valley County, North Dakota, 58621, United States', 'boundingbox': ['46.9048200', '46.9271630', '-104.0288210', '-103.9865500']}]
# [{'place_id': 307866901, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6603662, 'lat': '32.9315089', 'lon': '-95.8713542', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4569458819436982, 'addresstype': 'village', 'name': 'Point', 'display_name': 'Point, Rains County, Texas, United States', 'boundingbox': ['32.9168350', '32.9464500', '-95.8825200', '-95.8505030']}]
# [{'place_id': 350080397, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 12814094, 'lat': '6.4295092', 'lon': '-162.4073100', 'class': 'boundary', 'type': 'protected_area', 'place_rank': 25, 'importance': 0.6840175561954019, 'addresstype': 'protected_area', 'name': 'Kingman Reef National Wildlife Refuge', 'display_name': 'Kingman Reef National Wildlife Refuge, United States', 'boundingbox': ['6.1779744', '6.6514388', '-162.6816297', '-162.1339885']}]
# [{'place_id': 335848742, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 365922994, 'lat': '42.3595655', 'lon': '-71.0519869', 'class': 'railway', 'type': 'station', 'place_rank': 30, 'importance': 0.370994928094282, 'addresstype': 'railway', 'name': 'Aquarium', 'display_name': 'Aquarium, State Street, Waterfront, North End, Boston, Suffolk County, Massachusetts, 02109, United States', 'boundingbox': ['42.3545655', '42.3645655', '-71.0569869', '-71.0469869']}]
# [{'place_id': 304059034, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 181448, 'lat': '46.9180689', 'lon': '-104.0043728', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4540735774087027, 'addresstype': 'town', 'name': 'Beach', 'display_name': 'Beach, Golden Valley County, North Dakota, 58621, United States', 'boundingbox': ['46.9048200', '46.9271630', '-104.0288210', '-103.9865500']}]
# [{'place_id': 277669317, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 264304755, 'lat': '4.8206800', 'lon': '-52.3630528', 'class': 'aeroway', 'type': 'aerodrome', 'place_rank': 30, 'importance': 0.45039779319602985, 'addresstype': 'aeroway', 'name': 'Aéroport de Cayenne - Félix Éboué', 'display_name': 'Aéroport de Cayenne - Félix Éboué, Chemin de Paramana, Matoury, Cayenne, Guyane, 97351, France', 'boundingbox': ['4.8107614', '4.8304581', '-52.3818147', '-52.3418847']}]
# [{'place_id': 276717102, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 8979095793, 'lat': '14.4350606', 'lon': '-14.4917100', 'class': 'place', 'type': 'town', 'place_rank': 18, 'importance': 0.16005000152590218, 'addresstype': 'town', 'name': 'Payar', 'display_name': 'Payar, Communauté rurale de Payar, Arrondissement de Kouthiaba Wolof, Département de Koumpentoum, Région de Tambacounda, Sénégal', 'boundingbox': ['14.3950606', '14.4750606', '-14.5317100', '-14.4517100']}]
# [{'place_id': 253661899, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 299133, 'lat': '64.9841821', 'lon': '-18.1059013', 'class': 'boundary', 'type': 'administrative', 'place_rank': 4, 'importance': 0.7851887881317666, 'addresstype': 'country', 'name': 'Ísland', 'display_name': 'Ísland', 'boundingbox': ['63.0859177', '67.3530000', '-25.0135069', '-12.8046162']}]
# [{'place_id': 396183242, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 18511221, 'lat': '40.9088675', 'lon': '-74.6571746', 'class': 'boundary', 'type': 'census', 'place_rank': 25, 'importance': 0.33632164909184187, 'addresstype': 'census', 'name': 'Landing', 'display_name': 'Landing, Port Morris, Roxbury Township, Morris County, New Jersey, 07850, United States', 'boundingbox': ['40.8921150', '40.9263170', '-74.6873550', '-74.6378540']}]
# [{'place_id': 252118302, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 11196481369, 'lat': '54.4375759', 'lon': '-0.8867826', 'class': 'natural', 'type': 'peak', 'place_rank': 18, 'importance': 0.1600375013351644, 'addresstype': 'peak', 'name': 'Heads', 'display_name': 'Heads, North Yorkshire, York and North Yorkshire, England, YO21 2NS, United Kingdom', 'boundingbox': ['54.4375259', '54.4376259', '-0.8868326', '-0.8867326']}]
# [{'place_id': 304374368, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 1739849, 'lat': '43.6733632', 'lon': '-96.2574328', 'class': 'boundary', 'type': 'administrative', 'place_rank': 12, 'importance': 0.5354457341769019, 'addresstype': 'county', 'name': 'Rock County', 'display_name': 'Rock County, Minnesota, United States', 'boundingbox': ['43.5000913', '43.8494878', '-96.4534603', '-96.0525649']}]
# [{'place_id': 275691780, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1792651260, 'lat': '35.2543349', 'lon': '-3.1148749', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.33045469695876417, 'addresstype': 'village', 'name': 'Bni Boughafer ⴰⵢⵜ-ⴱⵓⴳⴰⴼⴻⵔ بني بويافر', 'display_name': 'Bni Boughafer ⴰⵢⵜ-ⴱⵓⴳⴰⴼⴻⵔ بني بويافر, Iaazzanene إعزانن, Caïdat Iaazzanene قيادة, Cercle de Guelaia دائرة قلاية, Province de Nador إقليم الناظور, Oriental ⵜⴰⵏⴳⵎⵓⴹⵜ الشرقية, 62022, Maroc ⵍⵎⵖⵔⵉⴱ المغرب', 'boundingbox': ['35.2343349', '35.2743349', '-3.1348749', '-3.0948749']}]
# [{'place_id': 275691780, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1792651260, 'lat': '35.2543349', 'lon': '-3.1148749', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.33045469695876417, 'addresstype': 'village', 'name': 'Bni Boughafer ⴰⵢⵜ-ⴱⵓⴳⴰⴼⴻⵔ بني بويافر', 'display_name': 'Bni Boughafer ⴰⵢⵜ-ⴱⵓⴳⴰⴼⴻⵔ بني بويافر, Iaazzanene إعزانن, Caïdat Iaazzanene قيادة, Cercle de Guelaia دائرة قلاية, Province de Nador إقليم الناظور, Oriental ⵜⴰⵏⴳⵎⵓⴹⵜ الشرقية, 62022, Maroc ⵍⵎⵖⵔⵉⴱ المغرب', 'boundingbox': ['35.2343349', '35.2743349', '-3.1348749', '-3.0948749']}]
# [{'place_id': 275691780, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1792651260, 'lat': '35.2543349', 'lon': '-3.1148749', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.33045469695876417, 'addresstype': 'village', 'name': 'Bni Boughafer ⴰⵢⵜ-ⴱⵓⴳⴰⴼⴻⵔ بني بويافر', 'display_name': 'Bni Boughafer ⴰⵢⵜ-ⴱⵓⴳⴰⴼⴻⵔ بني بويافر, Iaazzanene إعزانن, Caïdat Iaazzanene قيادة, Cercle de Guelaia دائرة قلاية, Province de Nador إقليم الناظور, Oriental ⵜⴰⵏⴳⵎⵓⴹⵜ الشرقية, 62022, Maroc ⵍⵎⵖⵔⵉⴱ المغرب', 'boundingbox': ['35.2343349', '35.2743349', '-3.1348749', '-3.0948749']}]
# [{'place_id': 426597940, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 13420703362, 'lat': '35.9593817', 'lon': '-5.5887043', 'class': 'place', 'type': 'sea', 'place_rank': 2, 'importance': 0.598381056993653, 'addresstype': 'sea', 'name': 'Estrecho de Gibraltar - مضيق جبل طارق', 'display_name': 'Estrecho de Gibraltar - مضيق جبل طارق', 'boundingbox': ['35.9593317', '35.9594317', '-5.5887543', '-5.5886543']}]
# [{'place_id': 277669317, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 264304755, 'lat': '4.8206800', 'lon': '-52.3630528', 'class': 'aeroway', 'type': 'aerodrome', 'place_rank': 30, 'importance': 0.45039779319602985, 'addresstype': 'aeroway', 'name': 'Aéroport de Cayenne - Félix Éboué', 'display_name': 'Aéroport de Cayenne - Félix Éboué, Chemin de Paramana, Matoury, Cayenne, Guyane, 97351, France', 'boundingbox': ['4.8107614', '4.8304581', '-52.3818147', '-52.3418847']}]
# [{'place_id': 262633701, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1180740942, 'lat': '49.9892202', 'lon': '-2.2384698', 'class': 'natural', 'type': 'strait', 'place_rank': 22, 'importance': 0.6812807159773241, 'addresstype': 'strait', 'name': 'English Channel / La Manche', 'display_name': 'English Channel / La Manche', 'boundingbox': ['49.4859736', '50.4924668', '-5.5316217', '1.0546820']}]
# [{'place_id': 276059450, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 694277175, 'lat': '19.9076537', 'lon': '-13.1243627', 'class': 'landuse', 'type': 'cemetery', 'place_rank': 22, 'importance': 0.106716999313344, 'addresstype': 'cemetery', 'name': 'Teleb Mohamed Oel Chems Eddine dit Baba', 'display_name': 'Teleb Mohamed Oel Chems Eddine dit Baba, Adrar أدرار, Mauritanie موريتانيا', 'boundingbox': ['19.9075580', '19.9077361', '-13.1244626', '-13.1242590']}]
# [{'place_id': 422672197, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 13301120584, 'lat': '27.3851707', 'lon': '68.5884756', 'class': 'railway', 'type': 'station', 'place_rank': 30, 'importance': 0.45539959252673184, 'addresstype': 'railway', 'name': 'پیر کاٹپر', 'display_name': 'پیر کاٹپر, Khuhra Road, Goth Fatehpur, تعلقہ خیرپور, ضلع خیرپور, سکھر ڈویژن, پاکستان', 'boundingbox': ['27.3801707', '27.3901707', '68.5834756', '68.5934756']}]
# [{'place_id': 307866901, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 6603662, 'lat': '32.9315089', 'lon': '-95.8713542', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4569458819436982, 'addresstype': 'village', 'name': 'Point', 'display_name': 'Point, Rains County, Texas, United States', 'boundingbox': ['32.9168350', '32.9464500', '-95.8825200', '-95.8505030']}]
# [{'place_id': 13902986, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 303726, 'lat': '-7.5606030', 'lon': '-34.9959100', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.486378244138402, 'addresstype': 'municipality', 'name': 'Goiana', 'display_name': 'Goiana, Região Geográfica Imediata de Goiana-Timbaúba, Região Geográfica Intermediária do Recife, Pernambuco, Região Nordeste, 55900-000, Brasil', 'boundingbox': ['-7.7146245', '-7.4619974', '-35.0770000', '-34.8061842']}]
# [{'place_id': 196767052, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 291603739, 'lat': '35.1285791', 'lon': '72.6131643', 'class': 'waterway', 'type': 'river', 'place_rank': 19, 'importance': 0.14670935301747154, 'addresstype': 'river', 'name': 'Olal Khwar', 'display_name': 'Olal Khwar, Nalkot Derai, تحصیل خوازہ خیلہ, ضلع سوات, مالاکنڈ ڈویژن, خیبر پختونخوا, پاکستان', 'boundingbox': ['35.1242959', '35.1556448', '72.5369800', '72.6886203']}]
# [{'place_id': 307129041, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 115414, 'lat': '34.9789849', 'lon': '-101.9281915', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.5263618328802072, 'addresstype': 'town', 'name': 'Canyon', 'display_name': 'Canyon, Randall County, Texas, 79016, United States', 'boundingbox': ['34.9564970', '35.0285960', '-101.9546820', '-101.8658780']}]
# [{'place_id': 253661899, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 299133, 'lat': '64.9841821', 'lon': '-18.1059013', 'class': 'boundary', 'type': 'administrative', 'place_rank': 4, 'importance': 0.7851887881317666, 'addresstype': 'country', 'name': 'Ísland', 'display_name': 'Ísland', 'boundingbox': ['63.0859177', '67.3530000', '-25.0135069', '-12.8046162']}]
# [{'place_id': 335848742, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 365922994, 'lat': '42.3595655', 'lon': '-71.0519869', 'class': 'railway', 'type': 'station', 'place_rank': 30, 'importance': 0.370994928094282, 'addresstype': 'railway', 'name': 'Aquarium', 'display_name': 'Aquarium, State Street, Waterfront, North End, Boston, Suffolk County, Massachusetts, 02109, United States', 'boundingbox': ['42.3545655', '42.3645655', '-71.0569869', '-71.0469869']}]
# [{'place_id': 54274082, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 26521074, 'lat': '40.7594680', 'lon': '26.7443485', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.3252605844508426, 'addresstype': 'village', 'name': 'Mahmutköy', 'display_name': 'Mahmutköy, Keşan, Edirne, Marmara Bölgesi, Türkiye', 'boundingbox': ['40.7394680', '40.7794680', '26.7243485', '26.7643485']}]
# [{'place_id': 106118640, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 287228194, 'lat': '50.8080835', 'lon': '6.3788680', 'class': 'place', 'type': 'village', 'place_rank': 19, 'importance': 0.24404996673231694, 'addresstype': 'village', 'name': 'Pier', 'display_name': 'Pier, Jüngersdorf, Langerwehe, Kreis Düren, Nordrhein-Westfalen, 52379, Deutschland', 'boundingbox': ['50.7880835', '50.8280835', '6.3588680', '6.3988680']}]
# [{'place_id': 197624722, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 12321526, 'lat': '33.0752020', 'lon': '89.5167021', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.21935002950294058, 'addresstype': 'town', 'name': '雅曲乡', 'display_name': '雅曲乡, 双湖县 མཚོ་གཉིས་རྫོང།, 那曲市 ནག་ཆུ་ས་ཁུལ།, 西藏自治区 བོད་རང་སྐྱོང་ལྗོངས།, 中国', 'boundingbox': ['32.6482812', '36.4613772', '88.4461206', '90.1487531']}]
# [{'place_id': 312072265, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 89203065, 'lat': '39.0368933', 'lon': '-84.5285802', 'class': 'office', 'type': 'public_transport', 'place_rank': 30, 'importance': 0.3341835968599259, 'addresstype': 'office', 'name': 'Transit Authority of Northern Kentucky', 'display_name': 'Transit Authority of Northern Kentucky, Electric Drive, Lakeview, Fort Wright, Kenton County, Kentucky, 41012, United States', 'boundingbox': ['39.0362022', '39.0376226', '-84.5295342', '-84.5275331']}]
# [{'place_id': 17896451, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 315184400, 'lat': '-33.8718968', 'lon': '135.1708970', 'class': 'tourism', 'type': 'camp_site', 'place_rank': 30, 'importance': 2.8147554741695542e-05, 'addresstype': 'tourism', 'name': 'Sheringa Beach', 'display_name': 'Sheringa Beach, Sheringa Beach Road, Sheringa, District Council of Elliston, South Australia, 5607, Australia', 'boundingbox': ['-33.8723822', '-33.8713756', '135.1695973', '135.1718793']}]
# [{'place_id': 253661899, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 299133, 'lat': '64.9841821', 'lon': '-18.1059013', 'class': 'boundary', 'type': 'administrative', 'place_rank': 4, 'importance': 0.7851887881317666, 'addresstype': 'country', 'name': 'Ísland', 'display_name': 'Ísland', 'boundingbox': ['63.0859177', '67.3530000', '-25.0135069', '-12.8046162']}]
# [{'place_id': 304059034, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'relation', 'osm_id': 181448, 'lat': '46.9180689', 'lon': '-104.0043728', 'class': 'boundary', 'type': 'administrative', 'place_rank': 16, 'importance': 0.4540735774087027, 'addresstype': 'town', 'name': 'Beach', 'display_name': 'Beach, Golden Valley County, North Dakota, 58621, United States', 'boundingbox': ['46.9048200', '46.9271630', '-104.0288210', '-103.9865500']}]
# [{'place_id': 283840047, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 49367947, 'lat': '25.0227795', 'lon': '-80.4953503', 'class': 'place', 'type': 'locality', 'place_rank': 25, 'importance': 0.4135109987360803, 'addresstype': 'locality', 'name': 'Tavernier', 'display_name': 'Tavernier, Monroe County, Florida, 33070, United States', 'boundingbox': ['25.0149460', '25.0359480', '-80.5057560', '-80.4892050']}]
# [{'place_id': 277669317, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 264304755, 'lat': '4.8206800', 'lon': '-52.3630528', 'class': 'aeroway', 'type': 'aerodrome', 'place_rank': 30, 'importance': 0.45039779319602985, 'addresstype': 'aeroway', 'name': 'Aéroport de Cayenne - Félix Éboué', 'display_name': 'Aéroport de Cayenne - Félix Éboué, Chemin de Paramana, Matoury, Cayenne, Guyane, 97351, France', 'boundingbox': ['4.8107614', '4.8304581', '-52.3818147', '-52.3418847']}]
# [{'place_id': 259555068, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'node', 'osm_id': 1637578440, 'lat': '51.5131048', 'lon': '-0.0893749', 'class': 'railway', 'type': 'station', 'place_rank': 30, 'importance': 0.5295749754766899, 'addresstype': 'railway', 'name': 'Bank', 'display_name': 'Bank, Mansion House Place, Broadgate, Bank, City of London, Greater London, England, EC4N 8BJ, United Kingdom', 'boundingbox': ['51.5081048', '51.5181048', '-0.0943749', '-0.0843749']}]
# [{'place_id': 237811878, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 68334061, 'lat': '10.5528313', 'lon': '119.1116873', 'class': 'place', 'type': 'islet', 'place_rank': 20, 'importance': 0.13337858930342564, 'addresstype': 'islet', 'name': 'Lump', 'display_name': 'Lump, Roxas, Palawan, Mimaropa, Philippines', 'boundingbox': ['10.5513508', '10.5543542', '119.1094726', '119.1140699']}]

# %%
display(coord_notfound_3)
coord_notfound_3.count()
# Out:
#                      Date  Year        Type           Country  \
# 9            9th November  2025  Unprovoked  French Polynesia
# 13           14th October  2025  Unprovoked          Columbia
# 29              20th July  2025  Unprovoked    Canary Islands
# 35               4th July  2025  Unprovoked      South Africa
# 43    2025-05-26 00:00:00  2025  Unprovoked           Vanuatu
# ...                   ...   ...         ...               ...
# 2664          25-Jul-2001  2001  Unprovoked               USA
# 2715          06-Jan-2001  2001  Watercraft       NEW ZEALAND
# 2716          24-Dec-2000  2000  Unprovoked         AUSTRALIA
# 2755          21-Aug-2000  2000  Unprovoked               USA
# 2804             Mar-2000  2000  Unprovoked               USA
#
#                                         Location                    Activity  \
# 9                                    Hakahau Bay                    Swimming
# 13                             Catagena Province        Swimming with sharks
# 29                                  Los Mollinas      Surfing (Hydrofoiling)
# 35                          Mfazazana Hibberdene                     Fishing
# 43                          Espiitu Santo Island                    Swimming
# ...                                          ...                         ...
# 2664                   Taverniier, Monroe County                         NaN
# 2715                         Sandy Bay/Whananaki                    Kayaking
# 2716                                Flinders Cay                Scuba diving
# 2755  Bouges Bank, Emerald Isle, Carteret County  Swimming out to porpoises
# 2804           Midnight Lump (38 miles offshore)                Spearfishing
#
#                       Name Sex  Age  \
# 9     Not stated (Dentist)   M   40
# 13              Male child   M   14
# 29                 Unknown   M    ?
# 35            Unknown male   M   37
# 43                   Tumas   M   14
# ...                    ...  ..  ...
# 2664                  male   M  NaN
# 2715    Dr. Michael Hogan    M  NaN
# 2716                  male   M   23
# 2755                  male   M  NaN
# 2804           Kurt Bickel   M   39
#
#                                                  Injury Fatal Y/N  \
# 9                                    Deep Gash to bicep         N
# 13                                   Severe hand injury         N
# 29               Lacerations to left leg above the knee         N
# 35                             Mltiple injuries to body         Y
# 43    Multiple injuries to body one hand and leg bit...         Y
# ...                                                 ...       ...
# 2664                                       Minor injury         N
# 2715                            No injury, kayak bitten         N
# 2716                                        Hand bitten         N
# 2755  Severe gash to left hand above wrist, almost s...         N
# 2804               No injury to diver, speargun damaged         N
#
#                                              Species  CountryCode   latitude  \
# 9                                            3m shark          PF  30.248169
# 13                                       Nurse shark           CA  46.102954
# 29                                       Undetermined          ES  37.493177
# 35                                      Undetermined           ZA -30.571944
# 43                                         Not stated          VU  64.984182
# ...                                               ...         ...        ...
# 2664                                              NaN          US  25.022779
# 2715                                      White shark          NZ        NaN
# 2716                                              NaN          AU   4.820680
# 2755                                              NaN          US  51.513105
# 2804  Shortfin mako shark, 3 m to 3.4 m [10' to 11']           US  10.552831
#
#        longitude      cleaned_location
# 9     -85.659363           Hakahau Bay
# 13     11.129743     Catagena Province
# 29     -2.150670          Los Mollinas
# 35     30.573611  Mfazazana Hibberdene
# 43    -18.105901  Espiitu Santo Island
# ...          ...                   ...
# 2664  -80.495350            Taverniier
# 2715         NaN    Sandy BayWhananaki
# 2716  -52.363053          Flinders Cay
# 2755   -0.089375           Bouges Bank
# 2804  119.111687         Midnight Lump
#
# [115 rows x 16 columns]
# Date                115
# Year                115
# Type                115
# Country             115
# Location            115
# Activity            111
# Name                113
# Sex                 111
# Age                  84
# Injury              114
# Fatal Y/N           112
# Species              80
# CountryCode         115
# latitude             94
# longitude            94
# cleaned_location    115
# dtype: int64

# %%
coord_notfound_4 = coord_notfound_3.loc[coord_notfound_3["latitude"].isna()].copy()
coord_notfound_4.to_csv("/Users/emilywu/Desktop/DataLiteracy/MiniProjekt/noCoordFound_4.csv")
display(coord_notfound_4)
# Out:
#                       Date  Year        Type           Country  \
# 68     2024-12-30 00:00:00  2024  Unprovoked        Mozambique
# 188            28-May 2023  2023  Unprovoked     NEW CALEDONIA
# 209            09-Apr-2023  2023  Unprovoked               USA
# 289            01-Jun-2022  2022  Unprovoked         AUSTRALIA
# 423            02-Feb-2021  2021  Watercraft         AUSTRALIA
# 424            02-Feb-2021  2021  Watercraft               USA
# 763             9-Mar-2018  2018  Unprovoked         AUSTRALIA
# 834            31-Jul-2017  2017  Unprovoked               USA
# 991            23-Jun-2016  2016  Unprovoked      SOUTH AFRICA
# 1013           02-May-2016  2016    Provoked       NEW ZEALAND
# 1077           17-Oct-2015  2015  Unprovoked        MOZAMBIQUE
# 1178           10-Mar-2015  2015    Provoked            MEXICO
# 1179           07-Mar-2015  2015  Unprovoked  FRENCH POLYNESIA
# 1372           14-Aug-2013  2013  Unprovoked               USA
# 1656           21-May-2011  2011  Unprovoked     NEW CALEDONIA
# 1762           03-May-2010  2010  Unprovoked        MADAGASCAR
# 1811  Reported 29-Oct-2009  2009  Unprovoked        MOZAMBIQUE
# 1846           07-Jul-2009  2009  Unprovoked      SOUTH AFRICA
# 2325           02-May-2005  2005  Unprovoked               USA
# 2589           03-Jun-2002  2002  Unprovoked      SOUTH AFRICA
# 2715           06-Jan-2001  2001  Watercraft       NEW ZEALAND
#
#                              Location                              Activity  \
# 68                                  ?                                Diving
# 188                            Twagne                          Spearfishing
# 209                     Kewalos, Oahu                               Surfing
# 289   Oyster Stacks near Exmouth12h15                              Swimming
# 423                            Gleneg                          Surf skiing
# 424                        Ukumehama                               Kayaking
# 763                          Winkipop                               Surfing
# 834         Jacksonvlle, Duval County                          Skimboarding
# 991                           Ryspunt                          Spearfishing
# 1013                        Cormandel                               Fishing
# 1077          Nahaduga, Inhambane Bay                    Fishing for shrimp
# 1178                         Mazlatan                               Fishing
# 1179          Tupapati, Hikueru Atoll                  Sitting in the water
# 1372                    Makenat, Maui                            Snorkeling
# 1656                           Kendec                         Kite Boarding
# 1762      Ambatolaoka, Nosy Be Island                          Scuba diving
# 1811                    Off Vilanculo                          Spearfishing
# 1846          Jogensfontein, Stilbaai                               Surfing
# 2325                  Noreiga's, Maui                               Surfing
# 2589                   Off Mkhambati   Snorkeling (filming the sardine run)
# 2715              Sandy Bay/Whananaki                              Kayaking
#
#                              Name Sex        Age  \
# 68                   Unknown Male  M           ?
# 188                          male   M         42
# 209                   Mike Morita   M         58
# 289                           NaN   F        NaN
# 423                    Jad French   M         17
# 424   Daniel and Tristan Sullivan   M  45 and 15
# 763                  Lachie Brown   M         18
# 834                Colton McCarty   M         15
# 991                      Rene Nel   M         43
# 1013                         male   M         39
# 1077              Albertina Cavel   F         35
# 1178          David Villegas Mora   M         36
# 1179                         male   M  18 months
# 1372               Jana Lutteropp   F         20
# 1656                  Nathan ____   M         15
# 1762                Michel Touzet   M         59
# 1811               Mark Rogotzki    M        NaN
# 1846                 Paul Buckley   M         37
# 2325                   Scott Hoyt   M         47
# 2589                   Tony White   M         50
# 2715           Dr. Michael Hogan    M        NaN
#
#                                                  Injury Fatal Y/N  \
# 68    Diving for sea urchins attacked by shark injur...         Y
# 188               Fatal, bite to leg, shoulder and head         Y
# 209                             Injuries to right foot          N
# 289                                        Minor injury         N
# 423                          No injury, surf ski bitten         N
# 424                             No injury, kayak bitten         N
# 763                          Minor injury, ankle grazed         N
# 834                            Lacerations to lower leg         N
# 991                   Injuries to left leg & right hand         N
# 1013      Foot bitten by landed shark PROVOKED INCIDENT         N
# 1077                                              FATAL         Y
# 1178  Right hand bitten by hooked shark PROVOKED INC...         N
# 1179                                       Thigh bitten         N
# 1372                                              FATAL         Y
# 1656                                Thigh bitten, FATAL         Y
# 1762                         Lacerations to arm & chest         N
# 1811                           Left ankle & foot bitten         N
# 1846                                         Leg bitten         N
# 2325                           No injury, board damaged         N
# 2589                                   Upper arm bitten         N
# 2715                            No injury, kayak bitten         N
#
#                                      Species  CountryCode  latitude  \
# 68                                    Unknown          MZ       NaN
# 188                                       NaN          NC       NaN
# 209                       Tiger shark, 8'-10'          US       NaN
# 289                                       NaN          AU       NaN
# 423                       Bronze whaler shark          AU       NaN
# 424                               White shark          US       NaN
# 763                               1.8 m shark          AU       NaN
# 834                                       NaN          US       NaN
# 991                               White shark          ZA       NaN
# 1013                  Mako shark, 1.5 m [5']           NZ       NaN
# 1077                                      NaN          MZ       NaN
# 1178                                      NaN          MX       NaN
# 1179                     Blacktip Reef shark           PF       NaN
# 1372                             Tiger shark?          US       NaN
# 1656                        Tiger shark, 2.8m          NC       NaN
# 1762                                      NaN          MG       NaN
# 1811                            Zambesi shark          MZ       NaN
# 1846                                      NaN          ZA       NaN
# 2325                   Tiger shark, 3 m [10']          US       NaN
# 2589  1.5 to 2.5 m [5' to 8.25'] copper shark          ZA       NaN
# 2715                              White shark          NZ       NaN
#
#       longitude    cleaned_location
# 68          NaN
# 188         NaN              Twagne
# 209         NaN             Kewalos
# 289         NaN        Exmouth12h15
# 423         NaN              Gleneg
# 424         NaN           Ukumehama
# 763         NaN            Winkipop
# 834         NaN         Jacksonvlle
# 991         NaN             Ryspunt
# 1013        NaN           Cormandel
# 1077        NaN            Nahaduga
# 1178        NaN            Mazlatan
# 1179        NaN            Tupapati
# 1372        NaN             Makenat
# 1656        NaN              Kendec
# 1762        NaN         Ambatolaoka
# 1811        NaN           Vilanculo
# 1846        NaN       Jogensfontein
# 2325        NaN            Noreigas
# 2589        NaN           Mkhambati
# 2715        NaN  Sandy BayWhananaki

# %% [markdown]
# Putting all coordinates together

# %%
def update_coords(target_df, source_df):
    mask = source_df["latitude"].notna() & source_df["longitude"].notna()
    target_df.loc[source_df.index[mask], ["latitude", "longitude"]] = \
        source_df.loc[mask, ["latitude", "longitude"]]

# %%
update_coords(df, coord_notfound)
update_coords(df, coord_notfound_2)
update_coords(df, coord_notfound_3)
update_coords(df, coord_notfound_4)

# %% [markdown]
# Hardcoding the last 21 missing coordinates

# %%
manual_coords = {
    68:  (-15.03466, 40.73447),   # Mozambique, unknown -> Küste 

    188: (-22.2760, 166.4580),    # NEW CALEDONIA "Twagne" -> grob Nouméa / Küste
    209: (21.2850, -157.8620),    # USA "Kewalos, Oahu" -> Kewalo Basin, Honolulu

    289: (-21.9330, 114.1290),    # AU "Exmouth..." -> Exmouth, WA
    423: (-34.9800, 138.5130),    # AU "Gleneg" -> Glenelg Beach, SA
    424: (20.8160, -156.6280),    # USA "Ukumehama" -> Ukumehame (Maui Westküste, grob)

    763: (-38.3700, 144.2550),    # AU "Winkipop" -> Surf spot bei Torquay, VIC
    834: (30.3320, -81.6550),     # USA "Jacksonvlle" -> Jacksonville, Florida

    991: (-34.8300, 20.0500),     # ZA "Ryspunt" -> grob Südküste (Kap-Region)
    1013:(-36.7610, 175.5020),    # NZ "Cormandel" -> Coromandel / Coromandel Peninsula

    1077:(-23.7700, 35.3900),     # MZ "Nahaduga, Inhambane Bay" -> Inhambane Bay (grob)
    1178:(23.2490, -106.4110),    # MX "Mazlatan" -> Mazatlán (Rechtschreibung)

    1179:(-17.5500, -142.6200),   # French Polynesia "Tupapati, Hikueru Atoll" -> Hikueru Atoll (grob)

    1372:(20.6560, -156.4430),    # USA "Makenat, Maui" -> Makena, Maui (grob)
    1656:(-22.2760, 166.4580),    # NEW CALEDONIA "Kendec" -> grob Nouméa / Küste

    1762:(-13.4000, 48.2000),     # Madagascar "Ambatolaoka, Nosy Be" -> Nosy Be / Ambatoloaka
    1811:(-21.9980, 35.3150),     # Mozambique "Vilanculo" -> Vilanculos Küste

    1846:(-34.4200, 21.3400),     # ZA "Jogensfontein, Stilbaai" -> Jongensfontein Küste
    2325:(20.8800, -156.6830),    # USA "Noreiga's, Maui" -> Lahaina Gegend (grob)

    2589:(-31.3100, 29.9900),     # ZA "Mkhambati" -> Mkhambati Nature Reserve Küste
    2715:(-35.5100, 174.4800),    # NZ "Sandy Bay/Whananaki" -> Whananaki / Northland Küste
}

# %%
for idx, (lat, lon) in manual_coords.items():
    df.loc[idx, ["latitude", "longitude"]] = lat, lon

# %% [markdown]
# just for testing and trying out purposes

# %%
coord_notfound.to_csv("/Users/emilywu/Desktop/DataLiteracy/MiniProjekt/noCoordFound.csv")

# %%
df.to_csv("/Users/emilywu/Desktop/DataLiteracy/MiniProjekt/clean_shark_attacks.csv")

# %%
res = get_coordinates("Ka alu‘alu Beach", "AU")
print(res[0]["lat"])
print(json.dumps(res, indent=4))
# Out:
# -33.6365039
# [
#     {
#         "place_id": 19744246,
#         "licence": "Data \u00a9 OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#         "osm_type": "relation",
#         "osm_id": 2918144,
#         "lat": "-33.6365039",
#         "lon": "151.3290299",
#         "class": "boundary",
#         "type": "administrative",
#         "place_rank": 18,
#         "importance": 0.32173239253715025,
#         "addresstype": "suburb",
#         "name": "Avalon Beach",
#         "display_name": "Avalon Beach, Northern Beaches, Northern Beaches Council, New South Wales, 2107, Australia",
#         "boundingbox": [
#             "-33.6432341",
#             "-33.6142715",
#             "151.3115063",
#             "151.3438980"
#         ]
#     }
# ]

# %%
def get_powerbi_metadata(headers, api_endpoint, **query_params):
		"""
		send GET request with query parameters
		"""
		response = requests.get(api_endpoint, headers=headers, params=query_params)
		print(f"Status-Code: {response.status_code}")

		if response.status_code == 200:
			return response.json()
	
		else:
			response.raise_for_status()

# %%
res = get_powerbi_metadata("", "https://nominatim.openstreetmap.org/search", **{"q": "Ka alu alu Bay", "format": "json", "countrycodes": "aus", "limit": 1})
print(json.dumps(res, indent=4))
# Out:
# Status-Code: 200
# []

# %%
res = get_coordinates("", "https://geocoding-api.open-meteo.com/v1/search", **{"name": 'Avalon+Beach', "count": "10", "language": "en", "format": "json", "countryCode": "AU"})
# Out:
# Status-Code: 200
# {
#     "results": [
#         {
#             "id": 2177471,
#             "name": "Avalon Beach",
#             "latitude": -33.63588,
#             "longitude": 151.32903,
#             "elevation": 9.0,
#             "feature_code": "PPLX",
#             "country_code": "AU",
#             "admin1_id": 2155400,
#             "admin2_id": 12047279,
#             "timezone": "Australia/Sydney",
#             "country_id": 2077456,
#             "country": "Australia",
#             "admin1": "New South Wales",
#             "admin2": "Northern Beaches"
#         }
#     ],
#     "generationtime_ms": 0.5942583
# }
